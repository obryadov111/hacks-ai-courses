# %%
import requests      # Для запросов по API
import json          # Для обработки полученных результатов
import time          # Для задержки между запросами
import os            # Для работы с файлами
import re
import pandas as pd  # Для формирования датафрейма с результатами
from bs4 import BeautifulSoup

# %%
def get_vacancy(query = 'ML'):
    params = {
        'text': query,         # Поиск текста
        # 'area': area,         # Поиск в зоне
        # 'page': page,         # Номер страницы
        'per_page': 100       # Кол-во вакансий на 1 странице
    }   
    req = requests.get('https://api.hh.ru/vacancies', params)
    data = json.loads(req.content.decode())
    req.close()
    return data

def get_skills(vacancy):
    req = requests.get(vacancy['url'])
    data = json.loads(req.content.decode())
    req.close()
    result = []
    for i in data['key_skills']:
        result.append(i['name'])
    return result

def get_desc(vacancy):
    req = requests.get(vacancy['url'])
    data = json.loads(req.content.decode())
    req.close()
    soup = BeautifulSoup(data['description'], 'html.parser')

    # Извлекаем текст из HTML
    text = soup.get_text()
    return text

def get_requirements(vacancy):
    text1 = vacancy['snippet']['requirement']
    text2 = vacancy['snippet']['responsibility']
    pattern = r'( и т\.?\s?д\.?| и др\s?\.?|и\/или|или| и )'
    cleaned_text1 = re.sub(pattern, ' ', text1, flags=re.IGNORECASE)
    cleaned_text2 = re.sub(pattern, ' ', text2, flags=re.IGNORECASE)
    pattern = r'(\.\.\.\n\.\.\.)'
    cleaned_text1 = re.sub(pattern, ' ', cleaned_text1, flags=re.IGNORECASE)
    cleaned_text2 = re.sub(pattern, ' ', cleaned_text2, flags=re.IGNORECASE)
    pattern = r'([A-ZА-Я]([^\.]|(\. [a-zа-я]))+)\.?\ ?'
    cleaned_text1 = re.findall(pattern, cleaned_text1, flags=re.IGNORECASE)
    cleaned_text2 = re.findall(pattern, cleaned_text2, flags=re.IGNORECASE)
    return cleaned_text1 + cleaned_text2

# %%
from razdel import tokenize, sentenize

from navec import Navec
import slovnet

navec = Navec.load("navec_news_v1_1B_250K_300d_100q.tar")
syntax = slovnet.Syntax.load("slovnet_syntax_news_v1.tar")

syntax. navec(navec)

def seg_text(doc):
    if isinstance(doc, str):
        doc = {"text": doc}
    
    doc["tokens"] = []

    for sent in sentenize(doc["text"]):
        doc["tokens"].append([_.text for _ in tokenize(sent.text)])
    
    return doc

import nltk
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer

nltk.download("stopwords")
analyzer = MorphAnalyzer()
stop_words = stopwords.words("russian")
pos = {'NOUN', 'ADJF', 'ADJS', 'VERB', 'INFN', 'PRTF', 'PRTS'}

def extract_candidates(doc: dict, stop_words: list = stop_words, pos: set = pos) -> dict:

    res = set()
    for sent in doc["tokens"]:
        for token in sent:
            if token in stop_words or token in res:
                continue

            parsed = analyzer.parse(token) [0]

            if parsed.tag.POS not in pos:
                continue

            res.add(token)
    doc["candidates"] = res
    return doc

def syntax_collocations(doc: dict, syntax: slovnet.api.Syntax = syntax) -> dict:
    syntax_colloc = []
    for sent in doc["tokens"]:

        syntax_markup = syntax(sent)
        sent_word_id = {}
        for token in syntax_markup. tokens:
            sent_word_id[token.id] = token.text
            
        for token in syntax_markup. tokens:
            if token.head_id!='@' and token.text in doc["candidates"]:
                try:
                    syntax_colloc.append(sent_word_id[token.head_id] + ' ' + token.text)
                except :
                    pass
    doc["collocations"] = set(syntax_colloc)

    return doc
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/datalore/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# import spacy
import json
from pymorphy2 import MorphAnalyzer
from transliterate import translit, get_available_language_codes

from natasha import (
    Segmenter,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    MorphVocab,
    Doc
)
# Загрузка модели языка
# nlp = spacy.load("en_core_web_sm")
pattern  = r'([A-ZА-Я][a-zа-яA-ZА-Я\s\/\,]+[\:|\?|\-])\ *\n'
pattern1 = r'(требован)|(хотели.+видеть)|(ждем.+от)|(ожидаем)|(ожидания.+от)|(ждем.+)|(стек.+)'
pattern2 = r'(знан.+)|(опыт.*)|(навык.+)|(уме.+)|(.+сть)|(образов.+)|(работ.+)|(владе.+)|(понима.+)|(принци.+)|(стек.+)'\
           r'|(.+ний)|(.+чие)|(фрейм.+)|(.+ом)|(человек.+)|(уров.+)|(лет)|(рекл.+)|(вакан.+)|(получ.+)|(пользовате.+)|'\
           r'(предостав.+)|(труд.+)|(услов.+)|(откл.+)|(час.+)|(чел)|(чу.+)|(федер.+)'
pattern3 = r'[^\w]([a-zа-яA-ZА-Я]+[^;]+)[^\n+]'
pattern4 = r"[\s\w\d]"
pattern5 = r"[\s\,\.\+\/]+"
pattern6 = r"[a-zA-Z\d\s]+"

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
# Выполняем сегментацию текста
segmenter = Segmenter()
morph = MorphAnalyzer()



def get_tags_vacancy(text):
    soup = BeautifulSoup(text, 'html.parser')
    text = soup.get_text()
    blocks = re.findall(pattern, text.replace('\\n', ' '), re.MULTILINE)
    blocks = [i.lower() for block in blocks for i in block.split('\n')]
    req = [block for block in blocks if re.search(pattern1, block)]
    sec = None
    blk = []
    if len(req):
        for s in req:
            for j in range(blocks.index(s) + 1, len(blocks)):
                if not re.search(pattern2, blocks[j]):
                    sec = blocks[j]
            tmp = text.lower().split(s)[1].strip().strip(':').strip()
            if sec:
                blk.append(tmp.split(sec)[0].strip().strip(':').strip())
                sec = None
            else:
                blk.append(tmp)
    else:
        blk = [text.lower().strip()]

    
    tags = []
    tags1 = []
    tags2 = []
    for block in blk:    
        res = [j.replace('\n', ' ').replace('\t', ' ').replace('/', ', ') for j in re.findall(pattern3, block)]
        for text in res:
            doc = Doc(text)
            doc.segment(segmenter)
            doc.tag_morph(morph_tagger)
            doc.parse_syntax(syntax_parser)
            for token in doc.tokens:
                tag = "".join(re.findall(pattern4, token.text, re.MULTILINE))
                # tag = token.text
                if not re.search(pattern2, token.text) and len(tag) > 0:
                    if token.pos == 'NOUN':
                        tags1.append(token.text)
                        tags1.append(translit(token.text, 'ru', reversed=True))
                    elif token.pos == 'X':
                        tags.append(token.text)
                        tags.append(translit(token.text, 'ru'))

            for word in text.split():
                if re.search(pattern6, "".join(re.findall(pattern4, word, re.MULTILINE))):
                    tags.append("".join(re.findall(pattern4, word, re.MULTILINE)))
                    tags.append(translit("".join(re.findall(pattern4, word, re.MULTILINE)), 'ru'))


            doc1 = seg_text(text)
            doc1 = extract_candidates(doc1)
            doc1 = syntax_collocations(doc1)
            for tag in doc1["collocations"]:
                if not re.search(pattern2, tag):
                    clear_tag = " ".join([morph.normal_forms(token)[0] for token in tag.split()])
                    tags2.append(clear_tag)
                    if len(re.split(pattern5, clear_tag)):
                        for pod_tag in re.split(pattern5, clear_tag):
                            tags2.append(pod_tag)

    if len(tags) > 0:
        keywords = set(tags + tags2)
    else:
        keywords = set(tags1 + tags2)
    return keywords


for i in range(1, 21):
    f = open(f'/data/notebook_files/vacancies/{i}.txt')
    print(i)
    print(get_tags_vacancy(f.read()))
    print("---------")
# Out:
# 1
# {'numpy', 'бд такой', 'статистика математический', 'алгоритм обучение', 'гит', 'python пакет', 'вероятность', 'анализ', 'scipy', 'анализ данные', 'данные', 'постгрес', 'сцикит-леарн', 'сципы', 'pandas', 'писать код', 'вероятность статистика', 'код', 'пакет', 'пакет анализ', 'сцикитлеарн', 'обучение', 'docker', 'классический', 'алгоритм теория', 'пытхон', 'линуx', 'сqл', 'scikit-learn', 'статистика', 'scikitlearn', 'нумпы', 'python', 'доцкер', 'sql', 'структура', 'такой', 'обучение машинный', 'математический', 'пандас', 'писать', 'git', 'алгоритм', 'linux', 'бд', 'postgres', 'теория', 'алгоритм структура', 'алгоритм классический', 'машинный', 'теория вероятность'}
# ---------
# 2
# {'язык запрос', 'фора', 'конфигурация типовой', 'запрос управляемый', 'управляемый', 'один', 'управляемый фора', 'типовой', 'язык', 'конфигурация', '1с', 'конфигурация один', 'запрос'}
# ---------
# 3
# {'хотеть хотеть', 'развивать', 'желание создать', 'мышление аналитический', 'создать развивать', 'мышление', 'хотеть', 'тестирование', 'желание развиваться', 'настрой настрой', 'ит-сфера', 'бухгалтерский', 'высокий средний-специальный', 'настрой', 'желание', 'дело', 'учёт бухгалтерский', 'отношение дело', 'средний-специальный', 'проверять', 'настрой жизненный', '1с', 'жизненный', 'высокий', 'отношение', 'настрой неравнодушный', 'активный', 'развиваться ит-сфера', 'дело желание', 'мышление высокий', 'настрой активный', 'создать', 'настрой отношение', 'неравнодушный', 'проверять тестирование', 'мышление мышление', 'учёт', 'аналитический', 'активный позитивный', 'позитивный', 'развиваться', 'мышление проверять'}
# ---------
# 4
# {'wdmcwdmgpon', 'mikrotik', 'pptp', 'связь сертификат', 'сцрипц', 'присылать пожелание', 'больший', 'зависеть желание', 'телефония', 'описать', 'расти', 'пассивный активный', 'место рабочий', 'цисцо', 'пптпеоипвплсвррпнаццрипц', 'развиваться область', 'присылать резюме', 'нат', 'монтаж', 'язык иностранный', 'обучение', 'vrrp', 'pptpeoipvplsvrrpnatscripts', 'zabbix', 'оборудование сетевой', 'wдмцwдмгпон', 'активный', 'пассивный', 'лист', 'зависеть просьба', 'литература технический', 'перевод литература', 'nat', 'l2', 'мониторинг', 'собеседование', 'соблюдение мониторинг', 'высокий', 'связь мобильный', 'зависеть язык', 'воип', 'зависеть агентство', 'тк рф', 'отпуск', 'оборудование пассивный', 'описать присылать', 'соблюдение система', 'английский', 'лист высокий', 'просьба', 'язык английский', 'желание расти', 'классический', 'л3', 'vpls', 'плата', 'l', 'обучение соблюдение', 'определяться', 'лист монтаж', 'плата кадровый', 'соблюдение', 'воипклассической', 'wдм', 'заббиx', 'linux', 'гпон', 'оборудование классический', 'так сеть', 'л', 'связь профильный', 'тк', 'микротик', 'присылать', 'voipклассической', 'определяться результат', 'перевод', 'связь', 'беспокоить', 'scripts', 'зависеть обучение', 'eoip', 'желание', 'isp', 'предложить', 'цwдм', 'l3', 'агентство', 'исп', 'сертификат', 'рф', 'зависеть связь', 'сеть', 'язык', 'cisco', 'интерес', 'зависеть плата', 'вррп', 'результат собеседование', 'wdm', 'зависеть', 'лист больничный', 'мобильный', 'полный', 'место', 'оборудование', 'определяться интерес', 'пожелание', 'интерес предложить', 'wdm телефония', 'l3mikrotik', 'сетевой', 'cwdm', 'кадровый', 'voip', 'профильный', 'рабочий', 'иностранный', 'л3микротик', 'больший больший', 'gpon', 'резюме', 'система', 'линуx', 'вплс', 'просьба беспокоить', 'еоип', 'л2', 'так', 'соблюдение полный', 'область', 'лист отпуск', 'расти развиваться', 'технический', 'литература', 'обучение место', 'результат', 'развиваться', 'больничный', 'пптп'}
# ---------
# 5
# {'мстп', 'tracer', 'основа', 'модем маршрутизатор', 'ifconfig', 'еве', 'gns3', 'качество', 'цисцо', 'гнс', 'реальный', 'хциа', 'нат', 'строка ос', 'оборудование сетевой', 'администратор', 'обучать', 'gns', 'hcia', 'язык технический', 'nat', 'влан', 'оспф', 'лс', 'чтение', 'оборудование реальный', 'трацер', 'аныкеы', 'оси', 'anykey', 'материал', 'русский', 'гнс3', 'acl', 'английский', 'чтение материал', 'язык английский', 'мультиплексор', 'маршрутизатор', 'ифцонфиг', 'word', 'строка', 'ng', 'мицрософт', 'switching', 'linux др', 'linux', 'ос', 'ццна', 'ccna', 'рстп', 'в', 'microsoft', 'mstp', 'администратор системный', 'чтение язык', 'оборудование эмулятор', 'wорд', 'строка оборудование', 'модем', 'материал обучать', 'основа взаимодействие', 'packet', 'роутинг', 'pwd', 'routing', 'язык', 'ospf', 'в качество', 'cisco', 'инженер', 'инженер администратор', 'др', 'взаимодействие', 'оборудование', 'сетевой', 'osi', 'chmod', 'пацкет', 'vlan', 'нг', 'ls', 'чмод', 'цд', 'оборудование модем', 'инженер сетевой', 'линуx', 'взаимодействие строка', 'ацл', 'язык русский', 'rstp', 'эмулятор', 'технический', 'модем мультиплексор', 'сwитчинг', 'системный', 'пwд', 'cd', 'eve'}
# ---------
# 6
# {'опенфлоw', 'диагностика сетевой', 'с', 'отладка', 'переподписка', 'dci', 'оси', 'диагностика система', 'ниx', 'тцп', 'сетевой', 'мплс', 'динамический', 'анализ', 'евпн', 'mpls', 'osi', 'центр', 'данные', 'протокол маршрутизация', 'фабрика', 'технология сетевой', 'протокол', 'диагностика проблема', 'сеть центр', 'протокол протокол', 'построение', 'с система', 'инструкция инструкция', 'балансировка', 'isis', 'центр данные', 'маршрутизация', 'openflow', 'система', 'проблема', 'средство', 'анализ отладка', 'переподписка фабрика', 'представление переподписка', 'диагностика средство', 'сеть', 'система мониторинг', 'сдн', 'трафик', 'дци', 'bgp', 'ospf', 'оспф', 'sdn', 'переподписка представление', 'ип', 'бгп', 'представление', 'средство анализ', 'инструкция', 'ip', 'технология', 'tcp', 'балансировка трафик', 'диагностика', 'мониторинг', 'фабрика центр', 'проблема сетевой', 'evpn', 'маршрутизация динамический', 'nix', 'построение сеть', 'современный', 'центр современный', 'исис'}
# ---------
# 7
# {'ccna', 'оборудование', 'стп', 'сетевой', 'tacacs', 'stp', 'radius', 'технология сетевой', 'протокол', 'huawei', 'радиус', 'технология протокол', 'цисцо', 'фортинет', 'fortinet', 'оборудование сетевой', 'еигрп', 'тацацс', 'хуаwеи', 'sterra', 'оспф', 'bgp', 'ospf', 'cisco', 'бгп', 'eigrp', 'стерра', 'технология', 'ццна'}
# ---------
# 8
# {'snr', 'дмс год', 'сеть протокол', 'линуx-систем', 'средство техника', 'срок месяц', 'протокол', 'сергей', 'радонежский', 'техника оборудование', 'eltex др', 'оборудование сетевой', 'срок испытательный', 'производитель отечественный', 'иметь желание', 'ул', 'елтеx', 'техника вычислительный', 'ццнп', 'средство', 'срок', 'обучаться', 'bgp', 'оспф', 'радонежский радонежский', 'протокол семейство', 'год', 'вычислительный', 'иметь', 'протокол сетевой', 'qtech', 'linuxсистем', 'администрирование оборудование', 'тцп', 'снр', 'оспфбгп', 'тк рф', '5', 'английский', 'безопасность', 'построение', 'язык английский', 'римский', 'месяц', 'новый', 'обязательный', 'администрирование средство', 'обязательный приветствоваться', 'обязательный иметь', 'оборудование новый', 'ip', 'tcp', 'тк', 'отечественный', 'срок срок', 'минута метро', 'испытательный', 'радонежский минута', 'усергате', 'обязательный сертификат', 'минута', 'желание', 'станция римский', 'код безопасность', 'код', 'ospfbgp', 'linux-систем', 'маршрутизация', 'сертификат', 'рф', 'станция ул', 'eltex', 'сеть', 'техника', 'технический сервисный', 'язык', 'ospf', 'желание обучаться', 'ип', 'метро', 'приветствоваться', 'usergate', 'др', 'станция', 'оборудование', 'сетевой', 'семейство', 'протокол маршрутизация', 'сервисный', 'римский станция', 'линуxсистем', '3', 'qтеч', 'администрирование', 'технический', 'дмс', 'бгп', 'ccnp', 'построение сеть', 'радонежский сергей', 'станция метро', 'производитель'}
# ---------
# 9
# {'проводить', 'сменить обстановка', 'выходной', 'заботиться офис', 'redis', 'оптимизация', 'консультация юрист', 'страхование', 'новичок каждый', 'demo-день', 'joinов', 'k8s', 'demo-дни', 'данные', 'к', 'мероприятие яркий', 'неформальный', 'join-ов', 'программа', 'мыбоок', 'docker', 'обучение', 'случай', 'онлайн-библиотека', 'клуб разговорный', 'клуб страхование', 'развивать писать', 'хотеться', 'важный', 'sql', 'api', 'бренд', 'заботиться наставник', 'консультация', 'запрос', 'скидка', 'сервис', 'bestbenefits', 'развивать развивать', 'заботиться врач', 'выступать', 'год', 'заботиться мероприятие', 'обучение дополнительный', 'talks', 'развивать', 'погружать модный', 'конференция', 'наставник общение', 'общение', 'внешний', 'талкс', 'фашион', 'tech скидка', 'юрист', 'mybook', 'конференция внешний', 'английский', 'новичок', 'сменить', 'каталог коворкинг', 'статья', 'клуб', 'пытхон', 'заботиться клуб', 'йоин-ов', 'месяц', 'перформанце', 'клуб онлайн-библиотека', 'доцкер', 'теч', 'демо-дни', 'каждый', 'дважды', 'к8с', 'demoдни', 'нереляционный', 'performance', '40', 'оптимизация запрос', 'дважды год', 'коворкинг', 'lamoda', 'яркий', 'tech', 'заботиться выступать', 'случай событие', 'с', 'бесплатный', 'заботиться случай', 'мероприятие', 'гит', 'review', 'клуб английский', 'наставник', 'коворкинг санкт-петербург', 'день каждый', 's', 'сезон', 'дополнительный', 'день рабочий', 'тренд', 'коворкинг проводить', 'сезон каждый', 'бестбенефиц', '2х', 'страхование жизнь', 'сqл', 'каталог', 'заботиться скидка', 'база', 'api сервис', 'демодни', 'писать', 'мероприятие сезон', 'база данные', 'программа привилегия', 'погружать', 'заботиться хотеться', 'заботиться выходной', 'событие', 'хотеться сменить', 'личный', 'голанг', 'tech demo-день', 'выступать тренд', 'заботиться консультация', 'день', 'проводить развиваться', 'модный', 'месяц первый', 'программа бесплатный', 'заботиться программа', 'развивать бренд', 'ламода', 'данные оптимизация', 'golang', 'разговорный', 'первый', 'йоинов', 'офис', 'санкт-петербург', 'бренд личный', 'рабочий', 'fashion', 'событие важный', 'жизнь', 'python', 'заботиться день', 'привилегия', 'k', 'писать статья', 'врач', 'заботиться', 'git', 'общение неформальный', 'обстановка', 'апи', 'заботиться обучение', 'развиваться', 'ревиеw', 'редис', 'база нереляционный'}
# ---------
# 10
# {'фастапи', 'мс', 'тестирование', 'рест', 'постгрессqл', 'подход процесс', 'sql-server', 'лxмл', 'postgressql', 'соап', 'sqlserver', 'сqлсервер', 'подход современный', 'docker', 'процесс тестирование', 'подход', 'пытхон', 'fastapi', 'аиохттп', 'python', 'доцкер', 'процесс', 'ms', 'alembic', 'soap', 'алембиц', 'aiohttp', 'сqл-сервер', 'дянго', 'lxml', 'rest', 'современный', 'django'}
# ---------
# 11
# {'фастапи', 'нагрузить', 'оптимизация', 'данные', 'restful', 'рестфул', 'docker', 'приложение', 'api', 'планировщик задача', 'постгресqл', 'дрф', 'п', 'сqлите', 'django', 'сqлалчемы', 'postgresql', 'очередь', 'пытест', 'рефакторинг', 'написание код', 'задача', 'использование очередь', 'моцк', 'тест модульный', 'оптимизация рефакторинг', 'приложение нагрузить', 'sqlite', 'sqlalchemy', 'drf', 'flask', 'тест', 'пытхон', 'fastapi', 'курс профильный', 'использование', 'доцкер', 'mock', 'модульный', 'pytest', 'linux', 'дянго', 'написание тест', 'pydantic', 'гит', 'сqл-запросы', 'фласк', 'pandas', 'код', 'так п', 'оптимизация профилирование', 'fastapi приветствоваться', 'пыдантиц', 'база', 'база данные', 'приветствоваться', 'код асинхронный', 'написание', 'numpy', 'курс', 'рефакторинг код', 'профильный', 'профилирование', 'sql-запросы', 'sqlзапросы', 'линуx', 'нумпы', 'так', 'python', 'асинхронный', '2', 'пандас', 'git', '310', 'планировщик', 'апи', 'сqлзапросы', 'очередь планировщик'}
# ---------
# 12
# {'контроль версия', 'страхование', 'kotlin', 'зарплата', 'один контейнеризатор', 'оформить апгрейд', 'обсудить окончание', 'boot', 'один', 'мысqл', 'docker', 'обучение', 'случай', 'срок испытательный', 'зарплата платформа', 'раббит', 'рост', 'тренинг', 'затрата система', 'кафка', 'срок', 'оформить зарплата', 'rabbit', 'постгресqл', 'поддержка ментор', 'ментор', 'мq', 'транспорт', 'точка рост', 'qуаркус', 'postgresql', 'близкие', 'предложить близкие', 'достойный', 'обсудить график', 'платформа тренинг', 'система контроль', 'один брокер', 'график', 'зарплата достойный', 'спринг', 'апгрейд', 'ментор транспорт', '11', 'ментор развитие', 'vert', 'ментор база', 'спорт', 'предложить страхование', 'ментор наставник', 'контроль', 'доцкер', 'обсудить случай', 'active', 'ацтиве', 'брокер', 'страхование льготный', 'обсудить поддержка', 'kafka', 'страховка собеседовань', 'поиск', 'затрата здоровье', 'испытательный', 'наставник', 'платформа', 'java', 'затрата', 'предложить', 'оформить офис', 'обсудить забота', 'развитие', 'x', 'spring', 'mysql', 'котлин', 'kubernetes', 'здоровье', 'mq', 'база', 'ваш', 'ява', 'версия', 'орацле', 'верт', 'кубернетес', 'поддержка', 'точка', 'платформа гибридный', 'день', 'гибридный', 'оформить оформить', 'курс', 'льготный', 'обсудить', 'vertx', 'окончание', 'платформа курс', 'quarkus', 'боот', 'собеседовань', 'офис', '3', 'близкие ваш', 'забота', 'полис', 'вертx', 'окончание срок', 'система', 'страховка', 'micronaut', 'мицронаут', 'опеншифт', 'обсудить день', 'платформа обучение', 'поиск точка', 'затрата спорт', 'oracle', 'обучение развитие', 'оформить', 'контейнеризатор', 'обсудить полис', 'openshift'}
# ---------
# 13
# {'postgresql', 'kotlin', 'java', 'спринг', 'реляционный', 'боот', 'субд', 'spring', 'boot', 'docker', '2х', 'проектирование', 'субд реляционный', 'система', 'проектирование система', 'котлин', 'доцкер', 'kubernetes', 'ява', 'высоконагруженный', 'постгресqл', 'проектирование высоконагруженный', 'кубернетес'}
# ---------
# 14
# {'postgresql', 'написание', 'качественный красивый', 'unitтестов', 'фрамеwорк', 'гит', 'юнит', 'мавен', 'junit', 'java', 'спринг', 'качественный рабочий', 'реляционный', 'желание', 'framework', 'хибернате', '3', 'писать код', 'униттестов', 'рабочий', 'код', '11', 'качественный', 'spring', 'jira', 'docker', 'тест', 'желание писать', 'бд реляционный', 'написание unit-тест', 'hibernate', 'покрыть', 'сqл', 'йира', 'unit-тест', 'доцкер', 'кафка', 'sql', 'код качественный', 'градле', 'писать', 'ява', 'тестнг', 'унит-тестов', 'git', 'постгресqл', 'maven', 'gradle', 'unit-тестов', 'красивый', 'бд', 'покрыть тест', 'kafka', 'testng'}
# ---------
# 15
# {'1', 'скидка занятие', '30', 'озон', 'основа', 'рест', 'вебинар', 'test', 'конференция скидка', 'graphql', 'элемент', 'light', 'mobius', 'обмениваться', 'конфигурация', 'премиум', 'сервис иметься', 'бд', 'выступать', 'rest', 'носqл', 'лигхт', 'деплый мониторинг', 'доступ сервис', 'экосистема', 'курс страхование', 'дигитал', 'спринг', 'соап', 'развитие технологический', 'направление', 'переиспользовать', 'highload покрытие', 'полезный', 'занятие', 'разрабатывать приложение', 'пользование бесплатный', 'kafka', 'hello', 'петабайт', 'приложение мобильный', 'платформа', 'день каждый', 'хигхлоад', 'код', 'скидка корпоративный', 'развитие', 'центр единый', 'spring', 'скидка предложение', 'матемаркетинг', 'финтех', 'music', 'гильдия', 'ozon', 'доступ', 'инцидент', 'лаборатория', 'мобильный', 'создать атмосфера', 'ui', 'обмен', 'conference', 'выступать конференция', 'боот', 'разрабатывать', 'сценарий', 'жизнь', 'целый', 'ооп', 'platform', 'iot', 'spring подпроект', 'гильдия гильдия', 'гильдия инженер', 'стриминг', 'быть', 'партнёр фитнес', 'unit-тестами', 'агиле-методологиям', 'конфигурация мобильный', 'унит-тестами', 'подпроект', 'conf', 'framework', 'конференция университет', 'знать центр', 'обсервабилиты', 'unitтестами', 'смочь быть', 'gitlab', 'проектирование', 'знать система', 'страховка медицинский', 'sql', 'ит', 'кроссплатформенный', 'облачный', 'вдохновлять', 'платформа собственный', 'гильдия направление', 'мц', 'kion', 'датафест', 'ocean', 'внешний', 'желательный', 'занятие английский', 'значит проблема', 'цонференце', 'предстоять заниматься', 'библиотека', 'создавать разбавить', 'месяц', 'поддержать дорабатывать', 'новый', 'экосистема мтс', 'поддерживать друг', 'datafest', 'lowcode', 'застраховать', 'микросервис', 'знать предстоять', 'решать', 'застраховать месяц', 'разрабатывать сервис', 'статья наш', 'выступать курс', 'пользование подписка', 'подписка единый', 'технологический', 'предложение', 'rabbitmq', 'иметься', 'атмосфера', 'ява', 'микросервис желательный', 'подписка онлайн-кинотеатр', 'лаборатория собственный', 'фрамеwорк', '18', 'конференция архитектура', 'знать разрабатывать', 'агилеметодологиям', 'можно застраховать', '8000', 'поездка рубеж', 'переиспользовать финтех', 'проводить конференция', 'жизнь здоровье', 'проблема платформа', 'driven', 'разбираться код', 'рубеж', 'система видеоаналитик', 'mts', 'паттерн проектирование', 'techtalks', 'паттерн', 'предложение партнёр', 'течталкс', 'страхование', 'данные', 'узнать скидка', 'покрытие расход', 'перевод монолит', 'код существующий', 'devops', 'boot', 'площадка обмен', 'расход', 'кафка', 'финтех кроссплатформенный', 'покрытие', 'скидка', 'монолит', 'узнать', 'сервис', 'security', 'знать читать', 'перевод микросервис', 'фича', 'agileметодологиям', 'сецуриты', 'конференция', 'видеоаналитик', 'существующий', 'английский', 'знать поддержать', '11', 'корпоративный', 'статья', 'читат', 'развитие экосистема', 'курс библиотека', 'создавать создать', 'создавать', 'смочь', 'фитнес', 'web', 'уи', 'сценарий целый', 'бесплатный', 'внутренний', 'подписка', 'йокер', 'сервис мтс', 'nosql бд', 'друг друг', 'гитлаб', 'знать', 'разрабатывать переиспользовать', 'observability', 'платформ', 'дривен', 'читать', 'предстоять', 'проводить код-ревить', 'курс полезный', 'страхование жизнь', '20', 'читать мтс', 'сqл', 'кион', 'выступать проводить', 'создать', 'разрабатывать петабайт', 'premium', 'лоwцоде', 'партнёр', 'аи', 'wеб', 'застраховать родственник', 'мтс', 'финтех стриминг', 'мусиц', 'раббитмq', 'поддержать баланс', 'переиспользовать данные', 'университет', 'конфигурация новый', 'онлайн-кинотеатр', 'страховка', 'создавать конфигурация', 'конфигурация инженер', 'agile-методологиям', 'highload', 'девопс', 'можно', 'обмениваться поддерживать', 'лоw-цоде', 'создавать основа', 'профессиональный', 'проводить', 'поддержать', 'подписка сервис', 'рутина', 'собственный', 'направление данные', 'курс вебинар', 'проводить площадка', 'приложение', 'инженер гейминг', 'архитектура', 'проводить поездк ...
# ---------
# 16
# {'скидка занятие', 'цqл', 'вид спорт', 'server', 'культура развитой', 'проект интересный', 'коллектив', 'за счёт', 'обучение', 'начало', 'начало гибкий', 'ст василеостровский', 'культура корпоративный', 'дресс‑код', 'sql', 'сервер', 'изучение язык', 'скидка', 'ц', 'бд', 'взаимодействовать', 'дружный', 'повышение квалификация', 'пространство спб', 'коллектив профессионал', 'повышение', 'день оплачивать', 'конференция', 'конференция выставка', 'тк рф', 'wебприложений', 'пространство рабочий', 'отпуск', 'английский', 'вид различный', 'корпоративный', 'за', 'язык английский', 'день отпуск', 'интересный', 'спорт', 'квалификация', 'выставка', 'вид', 'занятие', 'отсутствие', 'начало день', 'м', 'развитой', 'тк', 'проводиться отсутствие', 'отсутствие дресс‑код', 'гибкий', 'культура онлайн‑библиотека', 'проект', 'дополнительный', 'день рабочий', 'проводиться соревнование', 'взаимодействовать бд', 'c', 'рф', 'сqл', 'ms', 'профессионал', 'коллектив дружный', 'язык', 'язык программирование', 'ст', 'т-сqл', 'кофе-точка', 'дополнительный день', 'различный', 'день', 'пространство', 'офис кофе-точка', 'мс', 'изучение', 'проводиться обучение', 't-sql', 'webприложений', 'счёт', 'оплачивать', 'офис', 'соревнование', 'рабочий', 'tsql', 'спб', 'онлайн‑библиотека', 'соревнование вид', 'ст м', 'проводиться начало', 'проводиться культура', 'культура', 'проводиться', 'день дополнительный', 'программирование', 'культура повышение', 'василеостровский'}
# ---------
# 17
# {'создание использование', 'цqл', 'mvc', 'redis', 'сервис система', 'данные', 'фича ооо', 'соответствие', 'автопитер пр-кт', 'раббит', 'бацкендразработка', 'sql', 'api', 'ит', 'asp', '103', 'запрос', 'rabbit', 'сервис', 'ц', 'мq', 'фича', 'пр-кт новгородский', 'высокий', 'цоре', 'кэширование', 'задача', 'core', 'спасибо заинтересоваться', 'wпф', 'автопитер строение', 'существующий', 'английский', 'swagger', 'сwаггер', 'wцф', 'сфера', 'в соответствие', 'проект существующий', 'английский технический', 'разбираться', 'фича задача', 'фича сервис', 'сопровождение проект', 'использование', 'спецификация', 'вид', 'создание', 'развитие сопровождение', 'высокий средний', 'аспнет', 'backendразработка', 'спасибо', 'технология служба', 'соответствие спецификация', 'нет', 'средний', 'внутренний', 'данные кэширование', 'в', 'wpf', 'проект', 'код', 'развитие', 'спасибо развитие', 'open', 'задача ваш', 'объектно-ориентированный', 'c', 'асп', 'в вид', 'сqл', 'ооо', 'пр-кт', 'распределённый', 'ms', 'mq', 'ваш', 'запрос создание', 'спасибо фича', 'т-сqл', 'wcf', 'написание запрос', 'опен', 'написание', 'мс', 'мвц', 't-sql', 'служба', 'соурце', 'net', 'строение', '3', 'автопитер', 'tsql', 'данные распределённый', '26', 'система', 'сфера ит', 'source', 'система внутренний', 'технология данные', 'технический', 'aspnet', 'технология', 'апи', 'разбираться код', 'сопровождение', 'программирование объектно-ориентированный', 'заинтересоваться', 'ооо автопитер', 'новгородский', 'программирование', 'редис'}
# ---------
# 18
# {'фронтенд язык', 'фронтенд база', 'цqл', 'контроль версия', 'рест', 'данные', 'js', 'gitlab', 'react', 'архитектура', 'орм-система', '# кросс', 'sql', 'являться стек', 'ит', 'являться система', 'фронтенд система', 'orm-система', 'постгресqл', 'ц', 'версийгитлаб', 'rest', 'сqлите', 'использовать', 'ормсистемами', 'postgresql', 'орм-системами', 'wпф', 'система контроль', 'html', 'база контейнеризатор', 'sqlite', 'версийgitlab', 'entityframework', 'xмл', 'классический', '# фронтенд', 'rest orm-система', 'субд кросс', 'контроль', 'структура', 'ormсистемами', 'алгоритм структура', 'фронтенд', 'нет', 'хтмл', 'wpf', 'платформа', 'солид', 'субд', 'гитлаб', 'orm-системами', '2х', 'c', 'javascript', 'сqл', 'реацт', 'ооп платформа', 'ентитыфрамеwорк', 'ms', 'база', 'язык', 'docke', 'йс', 'версия', 'алгоритм', 'база данные', 'т-сqл', 'ормсистема', 'xml', 'технология фронтенд', 'ддд', 'it', 'мс', 'архитектура микросервисный', 'ddd', 't-sql', 'сигналр', 'net', 'tsql', 'кросс', 'являться', 'микросервисный', 'стек', 'система', 'ormсистема', 'ооп', 'явасцрипт', 'solid', 'ms orm-система', '#', 'технология', 'signalr', 'алгоритм классический', 'контейнеризатор', 'технология использовать', 'доцке'}
# ---------
# 19
# {'поставить', 'вуе', 'nuxtjs', 'тыпесцрипт', 'хтмл', 'vue', 'решать', 'задача', 'следование применение', 'html', 'js', 'решать срок', 'применение', 'применение код-стандарт', 'код-стандарт', 'применение другой', 'другой', 'javascript', 'явасцрипт', 'нуxт', 'срок', 'typescript', 'йс', 'nuxt', 'задача поставить', 'решать задача', 'нуxтйс', 'следование'}
# ---------
# 20
# {'вёрстка веб-среда', 'bootstrap', 'вуе', 'технология вёрстка', 'хтмл', 'vue', 'бооцтрап', 'css', 'семантиц-уи', 'цсс', 'sass', 'паттернс', 'десигн', 'html', 'js', 'vuejs', 'patterns', 'базовый', 'вёрстка', 'технология базовый', 'semantic-ui', 'семантицуи', 'design', 'сасс', 'основный', 'javascript', 'явасцрипт', 'css3', 'веб-среда', 'цсс3', 'йс', 'технология', 'вуейс', 'semanticui', 'javascript основный', 'html5', 'хтмл5'}
# ---------

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_courses():
    url = 'https://gb.ru/courses/'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = [i.get('href') for i in soup.find_all('a', class_='card_full_link')]
    name = [i.span.text.strip().replace("\xa0", " ") for i in soup.find_all('div', class_='direction-card__title')]
    decription = [i.text.strip().replace("\xa0", " ") for i in soup.find_all('div', class_='direction-card__text')]
    term = [i.span.text.strip().replace("\xa0", " ") for i in soup.find_all('div', class_='direction-card__info-text ui-text-body--6')]
    courses = [(name[i], links[i], decription[i], term[i]) for i in range(len(links))]
    
    return courses

def course_parsing(url):
    pattr = "\((.+)\)"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html')
    skils = set()
    for description in soup.find_all('div', class_="promo-tech__item gkb-promo__tag _large ui-text-body--5"):
        tmp = set(description.span.text.strip().lower().split('/'))
        for tag in tmp:
            if len(re.findall(pattr, tag)):
                tmp = tmp | set([i.strip() for j in re.findall(pattr, tag) for i in j.split('/')]) | \
                      set([i.strip() for j in re.split(pattr, tag) for i in j.split('/')])
        skils = skils | tmp
    
    ignore_skills = set(['и другие', ''])
    return skils - ignore_skills

# %%
course_skils = [(i[0], i[1], course_parsing(i[1]), i[2], i[3]) for i in get_courses()]

df_course_skils = pd.DataFrame(course_skils, columns=["name", "url", "tags", "decription", "term"])
without_tags = df_course_skils[df_course_skils["tags"] == set()]

another_tags = []
with open("/data/notebook_files/tags.txt") as file:
    s = file.read().replace("\n", "").split(";")
    #print(s)
    #print(len(s))
    for i in range(0, len(s), 2):
        url = s[i].strip()
        tags = s[i+1].strip().replace("{", "").replace("}", "").replace("'", "").split(",")
        for i, t in enumerate(tags):
            tags[i] = t.strip()
        
        another_tags.append((url, set(tags)))
df_another_tags = pd.DataFrame(another_tags, columns=["url", "tags"])

df_courses = pd.DataFrame(course_skils, columns=["name", "url", "tags", "decription", "term"])
df_courses["id"] = df_courses.index

df_all_courses = pd.merge(df_courses,df_another_tags, on='url', how='left')
df_all_courses.loc[df_all_courses["tags_x"] == set(), "tags_x"] = df_all_courses.loc[df_all_courses["tags_y"] != set(), "tags_y"]
df_all_courses = df_all_courses.drop(columns=["tags_y"]).dropna()
df_all_courses = df_all_courses.rename(columns={"tags_x": "tags"})
drop_id = []
for i in df_all_courses.values:
    if i[3] == "":
        drop_id = i[5]
df_all_courses = df_all_courses.drop(drop_id)

all_tags = set()
for i in course_skils:
    all_tags = all_tags | i[2]

def check(input_tags, all_tags, df_course_skils):
    # Находим курс, который покрыват больше всего

    courses = df_course_skils.copy(deep=True)
    courses["id"] = courses.index
    
    best_id = []
    coverage = []
    input_tags = input_tags & all_tags
    print(input_tags)
    input_tags_len = len(input_tags)
    indexes = set(courses.index)

    courses["coverage"] = [0]*len(indexes)
    while len(input_tags)!=0 and len(best_id)<=4:
        max_tags_len = -1
        max_tags_id = -1
        min_unnecessary_tags_len = -1

        for i in indexes:
            course = courses.loc[i]
            tags_len = len(input_tags & course[2])
            unnecessary_tags = len(course[2] - input_tags)
            if max_tags_len < tags_len or ((max_tags_len == tags_len) and (unnecessary_tags < min_unnecessary_tags_len)):
                max_tags_len = tags_len
                max_tags_id = i
                min_unnecessary_tags_len = unnecessary_tags
        best_id.append(max_tags_id)
        courses.loc[max_tags_id, "coverage"] = round(max_tags_len/input_tags_len*100)
    
        input_tags = input_tags - courses.loc[max_tags_id][2]
        indexes = indexes - set([max_tags_id])
    
    ans = courses[courses.index.isin (best_id)]
    ans = ans.drop(columns=["id"])
    
    return ans.sort_values("coverage", ascending=False)
    
check({"wi-fi", "cmake", "http", "udp", "stl"}, all_tags, df_all_courses)
# Out:
# {'http', 'cmake', 'udp', 'wi-fi', 'stl'}
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>url</th>
#       <th>tags</th>
#       <th>decription</th>
#       <th>term</th>
#       <th>coverage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>41</th>
#       <td>Разработчик на C++ с нуля до Junior</td>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{git, linux, qt, tcp, http, udp, stl, c++, cmake}</td>
#       <td>Углубленная теория и больше практики. в конце ...</td>
#       <td>12 месяцев</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Разработчик умных устройств</td>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{iot, wi-fi, ble, c}</td>
#       <td>Научитесь проектировать, собирать и программир...</td>
#       <td>9 месяцев</td>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
url = 'https://gb.ru/geek_university/developer/product-manager-gb'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
navyk = [i.text.strip().replace("\xa0", " ").replace("  ", "\n") for i in soup.find_all('ul', class_='tools')]

nav = set()
for i in navyk:
    
    nav = nav | set([j.strip() for j in i.split("\n")])
ignore = set(["", 'и другие инструменты'])
nav = nav - ignore
nav
# Out:
# {'+ 41 инструмент',
#  'CustDev',
#  'Figma',
#  'JTBD',
#  'Lean Canvas',
#  'Product Market Fit',
#  'Retention',
#  'User Story',
#  'Ценностное предложение',
#  'Юнит-экономика'}

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>url</th>
#       <th>tags</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>https://gb.ru/s/ai-integration-specialist</td>
#       <td>{Product Market Fit, User Story, Юнит-экономик...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>https://gb.ru/geek_university/developer/qa-eng...</td>
#       <td>{RESTful API, JUnit, NoSQL, SQL, CSS, Pytest, ...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>https://gb.ru/geek_university/design/graphic-d...</td>
#       <td>{Adobe Photoshop, Figma, Adobe Illustrator, Ad...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{JUnit, SQL, PostgreSQL, CSS, Git, XML, Java D...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{Hive, SQL, Matplotlib, Scikit-Learn, Git, Pyt...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{JavaScript, Vue, WebSocket, SessionStorage, B...</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>https://gb.ru/geek_university/marketing/smm-ma...</td>
#       <td>{TGStat, Flyvi, Главред, Telegram, VN, VK, Goo...</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>https://gb.ru/geek_university/developer/qa-eng...</td>
#       <td>{Python, JavaScript, JUnit, Allure, NoSQL, Jav...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{FastAPI, SQL, CSS, Git, Python, XML, Django, ...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{SQL, GitHub, PostgreSQL, Xcode, Git, Swift Pl...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>https://gb.ru/geek_university/developer/progra...</td>
#       <td>{LibGDX, NoSQL, Java, Ethernet, SQL, CSS, HTML...</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>https://gb.ru/geek_university/engineer/datasci...</td>
#       <td>{Python, NoSQL, SQL, TensorFlow, Docker, ANNs,...</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>https://gb.ru/geek_university/games/game-designer</td>
#       <td>{Visual Studio, Unity, GitLab, Unreal Engine}</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>https://gb.ru/geek_university/management/accou...</td>
#       <td>{Excel, Google Таблицы, редакция 3.0, Бухгалте...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>https://gb.ru/geek_university/developer/projec...</td>
#       <td>{Excel, Kanban, Пирамида минто, Метод освоенно...</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>https://gb.ru/geek_university/marketing/e-comm...</td>
#       <td>{АстралЭДО, Canva, Ценообразование, Wildberrie...</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>https://gb.ru/geek_university/design/interface...</td>
#       <td>{UX-исследования, Figma, Photoshop, Agile, Til...</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>https://gb.ru/geek_university/design/graphic-gb</td>
#       <td>{InDesign, Illustrator, ТРИЗ, Колористика, Fig...</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>https://gb.ru/geek_university/developer/produc...</td>
#       <td>{Product Market Fit, User Story, Юнит-экономик...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
f = open("/data/notebook_files/vacancies/5.txt")
text = f.read()
tags = get_tags_vacancy(text)
check(tags, all_tags, df_course_skils)
# Out:
# {'cd', 'ospf', 'linux'}
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>url</th>
#       <th>tags</th>
#       <th>decription</th>
#       <th>term</th>
#       <th>coverage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>68</th>
#       <td>Сетевой инженер</td>
#       <td>https://gb.ru/geek_university/developer/archit...</td>
#       <td>{stp, linux, ip, bgp, tcp, python, ospf, fhrp}</td>
#       <td>Вы с нуля научитесь настраивать и обслуживать ...</td>
#       <td>12 месяцев</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>DevOps-инженер: быстрый старт в профессии</td>
#       <td>https://gb.ru/geek_university/developer/archit...</td>
#       <td>{ethernet, dns, nosql, kubernetes (k8s), unix,...</td>
#       <td>Вы изучите методы и инструменты DevOps, научит...</td>
#       <td>9 месяцев</td>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from navec import Navec
import slovnet

navec = Navec.load("navec_news_v1_1B_250K_300d_100q.tar")
syntax = slovnet.Syntax.load("slovnet_syntax_news_v1.tar")

syntax. navec(navec)
# Out:
# Syntax(
#     infer=SyntaxInfer(
#         model=Syntax(
#             emb=WordShapeEmbedding(
#                 word=NavecEmbedding(
#                     id='news_v1_1B_250K_300d_100q',
#                     indexes=Weight(
#                         shape=[250002,
#                          100],
#                         dtype='uint8',
#                         array=array([[176, 222, 248, ..., 244, 183, 191],
#                                [215, 200, 168, ..., 120, 217,  21],
#                                [ 83, 174,  54, ..., 106,  88, 251],
#                                ...,
#                                [133, 125, 123, ..., 124,  94,  24],
#                                [183,  49, 180, ..., 151, 167,  68],
#                                [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)
#                     ),
#                     codes=Weight(
#                         shape=[100,
#                          256,
#                          3],
#                         dtype='float32',
#                         array=array([[[ 0.01474531, -0.01112427,  0.35390645],
#                                 [-0.3327085 , -0.07963513, -0.0627134 ],
#                                 [ 0.08959492,  0.46132633, -0.4648361 ],
#                                 ...,
#                                 [-0.3382765 ,  0.22304447,  0.22137086],
#                                 [ 0.01749029,  1.0817952 , -0.464324  ],
#                                 [ 0.        ,  0.        ,  0.        ]],
#
#                                [[-0.21745344, -0.390481  , -0.03372274],
#                                 [ 0.02386222, -0.06201295,  0.43018696],
#                                 [ 0.00709212, -0.4080135 , -0.27760914],
#                                 ...,
#                                 [-0.15552734,  0.06172722,  0.41720647],
#                                 [-0.16846053,  0.29101175, -0.88510364],
#                                 [ 0.        ,  0.        ,  0.        ]],
#
#                                [[ 0.48526752, -0.1698238 ,  0.280273  ],
#                                 [ 0.2497128 ,  0.69259137,  0.16603692],
#                                 [ 0.37269542,  0.23635891,  0.7636631 ],
#                                 ...,
#                                 [-0.02258377, -0.28994206, -0.14447366],
#                                 [-0.07453094, -0.30251867,  0.04924757],
#                                 [ 0.        ,  0.        ,  0.        ]],
#
#                                ...,
#
#                                [[-0.23346834,  0.03953857,  0.05644926],
#                                 [ 0.8167329 ,  0.57257414, -0.6689591 ],
#                                 [-0.35154212, -0.4336423 ,  0.8149428 ],
#                                 ...,
#                                 [-0.06588681,  0.47523418, -0.39414153],
#                                 [-0.82925713, -0.3838403 , -0.12446608],
#                                 [ 0.        ,  0.        ,  0.        ]],
#
#                                [[ 0.44954434,  0.08727981, -0.19577788],
#                                 [-0.263664  , -0.31701726,  0.86469847],
#                                 [-0.4636477 ,  0.34382322,  0.8587696 ],
#                                 ...,
#                                 [ 0.40001723, -0.43998858,  0.17731333],
#                                 [-0.28567192, -0.07258819, -0.52291226],
#                                 [ 0.        ,  0.        ,  0.        ]],
#
#                                [[ 0.17092301, -0.30629456, -0.07775806],
#                                 [-0.02551726,  0.34224212,  1.0160226 ],
#                                 [ 0.03701574, -0.21370277, -0.05016475],
#                                 ...,
#                                 [-0.17239603,  0.18787187,  0.1649191 ],
#                                 [-0.0518746 , -0.14286335, -0.2335867 ],
#                                 [ 0.        ,  0.        ,  0.        ]]], dtype=float32)
#                     )
#                 ),
#                 shape=Embedding(
#                     weight=Weight(
#                         shape=[66,
#                          30],
#                         dtype='float32',
#                         array=array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#                                  0.        ,  0.        ],
#                                [-4.29559   , -0.9708808 , -0.20868096, ..., -2.7620022 ,
#                                 -1.4597015 ,  0.7747133 ],
#                                [-2.6610303 , -0.14590012, -0.12682201, ..., -3.297356  ,
#                                  0.04620038, -0.5347063 ],
#                                ...,
#                                [-1.5982444 , -1.0256423 , -0.8534012 , ...,  0.8214774 ,
#                                 -1.4664693 ,  3.3421364 ],
#                                [-0.5360805 ,  0.11748535, -0.26101592, ..., -1.2988034 ,
#                                  1.2259171 ,  0.1871909 ],
#                                [-0.73425084, -2.5813859 , -1.0604327 , ..., -0.6428045 ,
#                                 -2.412102  ,  0.23761465]], dtype=float32)
#                     )
#                 )
#             ),
#             encoder=CNNEncoder(
#                 layers=[CNNEncoderLayer(
#                      conv=Conv1d(
#                          weight=Weight(
#                              shape=[256,
#                               330,
#                               3],
#                              dtype='float32',
#                              array=array([[[ 1.0244976e+00, -5.0031180e+00, -1.2214642e+00],
#                                      [ 7.3754483e-01, -1.0832988e+01, -3.4668739e+00],
#                                      [-2.0903811e-01, -1.4542067e+00, -8.4766343e-02],
#                                      ...,
#                                      [-4.7213331e-02,  3.9822693e+00, -1.0929247e-01],
#                                      [-1.8611596e+00, -5.5627263e-01, -7.0187086e-01],
#                                      [-2.2007503e-01,  3.1954060e+00,  3.6297074e-01]],
#
#                                     [[-1.4873841e+00, -2.8000569e+00, -3.1917870e-01],
#                                      [ 1.4090018e-03, -3.0018395e-01, -4.2870185e-01],
#                                      [ 1.0642546e+00,  1.8882149e+00, -7.0755428e-01],
#                                      ...,
#                                      [ 7.5138605e-01,  6.1522019e-01, -3.8357174e-01],
#                                      [ 4.7751075e-01,  2.4190128e+00,  5.5342448e-01],
#                                      [ 2.3065202e-01, -6.3559100e-02, -8.7600976e-01]],
#
#                                     [[ 5.0989640e-01, -3.2184267e-01, -3.7931209e+00],
#                                      [-1.9540681e-01, -1.8243287e+00, -1.8470122e+00],
#                                      [ 1.2760385e+00, -3.7312779e+00,  2.7329972e+00],
#                                      ...,
#                                      [ 1.5775062e+00,  1.5459335e+00,  3.4159153e+00],
#                                      [ 9.4312036e-01,  3.8963103e+00, -2.8599014e+00],
#                                      [-7.7978057e-01, -2.1635253e+00,  5.0983292e-01]],
#
#                                     ...,
#
#                                     [[ 3.6529644e+00,  8.7389275e-02, -2.5122032e-01],
#                                      [-7.3139262e+00,  4.3257987e-01,  6.6627580e-01],
#                                      [ 5.0839243e+00, -1.3510802e+00, -4.1957551e-01],
#                                      ...,
#                                      [ 7.0459586e-01,  4.6832567e-01, -4.4784203e-01],
#                                      [-5.1452500e-01, -5.9217179e-01,  1.3503659e+00],
#                                      [-2.2384052e+00, -1.4054888e+00, -1.2625322e-01]],
#
#                                     [[ 7.4482012e-01,  1.3515611e+00,  4.6834227e-01],
#                                      [ 5.0276643e-01, -2.2450700e+00, -8.9887458e-01],
#                                      [ 7.3203671e-01,  9.0451866e-01,  1.3555036e+00],
#                                      ...,
#                                      [-5.4153669e-01,  1.8146979e+00, -3.7532704e+00],
#                                      [-3.7965872e+00,  7.5487590e-01, -1.3717017e+00],
#                                      [-1.4482572e+00,  3.1609526e+00, -1.0806049e+00]],
#
#                                     [[-1.4252362e+00, -1.5216286e+00, -2.0302843e-01],
#                                      [ 1.5665668e+00,  6.3223624e-01,  1.0287975e+00],
#                                      [-2.4135904e+00, -2.3625476e+00,  7.5171524e-01],
#                                      ...,
#                                      [-3.0733340e+00, -6.0305834e-01, -6.8657160e-01],
#                                      [ 1.6123843e+00, -1.1279875e+00, -6.1641937e-01],
#                                      [-3.0928516e+00, -1.7835644e+00, -3.8676488e-01]]], dtype=float32)
#                          ),
#                          bias=Weight(
#                              shape=[256],
#                              dtype='float32',
#                              array=array([-1.42959070e+00, -3.06109738e+00,  3.40610801e-04, -8.45732540e-02,
#                                     -2.70893788e+00, -1.64294147e+00, -2.34246039e+00, -3.48654962e+00,
#                                      4.0776944, 10.303813 ,  7.969253 ,  6.437305 , 10.14919  ,
#                                      8.238603 ,  7.9951496, 12.52038  ,  5.7315545, 12.013056 ,
#                                     70.21906  , 11.187748 ,  6.153853 , 11.727933 ,  9.466486 ,
#                                     15.003375 , 15.635    ,  4.6586175,  9.709963 ,  8.009386 ,
#                                      7.98649  ,  8.38264  , 11.666913 ,  5.398053 , 13.044513 ,
#                                      7.865928 ,  4.9496427, 19.945774 , 10.090746 , 14.95141  ,
#                                     11.101958 , 16.81956  , 10.583531 , 15.815706 , 17.322702 ,
#                                      4.3016477,  7.9825916, 17.84896  ,  8.108956 ,  4.5321455,
#                                      6.7542024,  7.982623 , 11.336803 , 12.123367 ,  4.3260856,
#                                     19.494318 , 28.62809  ,  3.6636302, 15.723491 , 24.042799 ,
#                                     30.772924 ,  9.961743 ,  2.51785  ,  6.755189 , 12.223013 ,
#                                     10.348204 ,  8.660616 ,  3.7735431,  9.195425 ,  4.466521 ,
#                                      9.185518 , 18.870342 ,  6.7902436, 41.843803 ,  9.690625 ,
#                                      3.1632805, 14.753921 ,  7.3882084,  9.899365 , 26.019669 ,
#                                      7.3925276], dtype=float32)
#                          )
#                      )
#                  ),
#                  CNNEncoderLayer(
#                      conv=Conv1d(
#                          weight=Weight(
#                              shape=[128,
#                               256,
#                               3],
#                              dtype='float32',
#                              array=array([[[-6.6037755 ,  1.7995607 , -1.4630579 ],
#                                      [-3.0462835 ,  2.401767  ,  1.0746418 ],
#                                      [-1.489946  , -4.0854697 , -1.7533803 ],
#                                      ...,
#                                      [ 1.237651  ,  0.35872108,  0.5416004 ],
#                                      [ 0.82074195, -0.7243774 ,  0.565603  ],
#                                      [-1.8801067 ,  1.2382983 ,  1.2259386 ]],
#
#                                     [[-3.2589157 , -0.7670381 ,  0.03745122],
#                                      [-1.3627807 , -0.5028801 , -0.2109963 ],
#                                      [-5.040082  ,  0.8068132 , -6.334596  ],
#                                      ...,
#                                      [ 0.5495189 ,  1.6849579 ,  0.08943846],
#                                      [ 0.2687987 ,  0.27911767, -0.7081338 ],
#                                      [ 0.36401972, -2.6137474 ,  0.98229176]],
#
#                                     [[ 4.0748005 , -0.2602804 , -2.1986113 ],
#                                      [ 4.8742747 , -1.2385147 ,  0.03478021],
#                                      [ 1.7212976 ,  2.3744833 ,  3.4041517 ],
#                                      ...,
#                                      [-0.7578073 , -8.321122  ,  0.8116748 ],
#                                      [ 3.7854729 ,  0.08936716, -0.66384524],
#                                      [ 2.1159635 ,  6.7592373 , -0.94590557]],
#
#                                     ...,
#
#                                     [[ 0.7754616 , -0.5407931 , -0.30631438],
#                                      [-3.314452  , -3.2080076 ,  0.63283676],
#                                      [ 2.739662  , -0.13018431, -0.03901127],
#                                      ...,
#                                      [-0.70224065,  2.0305157 ,  1.182753  ],
#                                      [-3.144221  , -0.15510252,  0.2762858 ],
#                                      [ 2.0721269 , -5.4922943 ,  0.89228857]],
#
#                                     [[-0.36433756,  1.0003127 ,  2.1156497 ],
#                                     -1.44480658e+00,  1.21391497e+01,  3.13568258e+00, -1.22348058e+00,
#                                      8.81673908e+00, -6.85309395e-02,  2.47980919e+01, -2.64115167e+00,
#                                      1.97173595e+01, -3.23031211e+00, -4.79831123e+00,  1.19550886e+01,
#                                     -3.64490986e+00, -7.75063086e+00, -5.72532988e+00,  1.35437365e+01,
#                                     -2.77330565e+00,  3.18690278e-02,  2.63686867e+01,  7.20410421e-02,
#                                     -2.86188078e+00, -6.24004459e+00,  1.08163042e+01,  1.26124334e+01,
#                                     -2.30060983e+00, -3.09471809e-03, -2.47611523e+00, -1.00417984e+00],
#                                    dtype=float32)
#                          ),
#                          padding=1
#                      ),
#                      relu=ReLU(),
#                      norm=BatchNorm1d(
#                          weight=Weight(
#                              shape=[128],
#                              dtype='float32',
#                              array=array([ 1.6995559,  1.7224308,  1.7110404,  3.0333123,  1.7566869,
#                                      1.5134989,  5.021312 ,  1.9957722,  2.2752478,  2.575862 ,
#                                      2.6184106,  2.3800673,  2.1498272,  2.5870874,  1.7147248,
#                                      2.3749695,  2.331365 ,  1.8953855,  1.7692006,  2.269274 ,
#                                      3.0230494,  1.749511 ,  1.5802288,  1.9050194,  3.506047 ,
#                                      2.0305133,  1.5421706,  1.5374618,  2.5713112,  1.5903076,
#                                      2.3095706,  2.5779324,  3.656656 ,  4.1398606,  1.8826269,
#                                      1.7872405,  4.11811  ,  2.8430133,  1.9828978,  4.5333467,
#                                      1.7413083,  2.3853688,  2.2323966,  2.0605865,  2.275049 ,
#                                      2.1996338,  2.373866 ,  1.7896492,  1.6660783,  2.7452407,
#                                      2.0768375,  2.5694025,  2.039307 ,  1.8322396,  1.9088626,
#                                      1.3682615,  1.5638533,  1.7231421,  1.6936598,  2.425063 ,
# ...
#                                      70.91964 , 186.49838 ,  34.256046, 197.76521 ,  87.32084 ,
#                                      34.266277, 120.43033 ,  13.040151,  60.781185,  22.37334 ,
#                                      72.89313 ,  80.37082 ,  95.29554 , 122.83468 ,  50.09711 ,
#                                      48.048634, 172.38042 ,  26.683475,  44.39224 , 174.06834 ,
#                                      49.859055, 162.9812  , 188.21484 ,  41.293236, 127.16957 ,
#                                     284.93524 ,  41.116867,  69.32475 , 105.74818 ,  28.955404,
#                                      85.94084 ,  51.72131 , 102.275116, 113.43009 ,  64.065544,
#                                      56.47549 , 170.82018 ,  46.14639 ,  44.426937], dtype=float32)
#                          ),
#                          std=Weight(
#                              shape=[64],
#                              dtype='float32',
#                              array=array([ 94.384796,  58.137497,  82.434555, 110.30252 , 140.51631 ,
#                                     116.53318 , 118.28178 , 126.66131 , 136.84717 ,  88.60395 ,
#                                      63.826443, 167.57191 , 153.81027 , 104.63931 ,  87.27527 ,
#                                     100.19873 , 142.60963 , 140.65717 , 134.04405 , 180.10367 ,
#                                     105.70991 , 113.73542 , 139.19797 ,  75.33582 , 126.811516,
#                                      97.61839 , 117.00565 ,  73.589836, 125.458046, 134.91463 ,
#                                      79.48098 , 114.29428 ,  45.287216,  83.042564,  55.50504 ,
#                                     110.5745  , 112.38095 , 129.9473  , 132.63405 ,  96.54451 ,
#                                      91.04547 , 174.87553 ,  80.9592  ,  87.14164 , 133.97737 ,
#                                      84.49551 , 115.628136, 126.194916,  75.661354, 138.00742 ,
#                                     148.12062 ,  75.043   ,  93.18691 , 154.50716 ,  68.29357 ,
#                                     136.18094 ,  89.66387 , 131.9161  , 108.474144,  90.200066,
#                                     110.12848 , 122.611984,  92.68119 ,  80.48752 ], dtype=float32)
#                          )
#                      )
#                  )]
#             ),
#             head=SyntaxHead(
#                 head=FF(
#                     proj=Linear(
#                         weight=Weight(
#                             shape=[64,
#                              32],
#                             dtype='float32',
#                             array=array([[-0.15187995, -1.5175064 , -0.1701577 , ...,  0.25019118,
#                                     -0.13696544, -0.53090453],
#                                    [ 0.00837084,  0.20958352, -0.28649905, ..., -0.58584523,
#                                      0.29844227, -0.37763402],
#                                    [-1.6240231 ,  0.78018224, -0.46609536, ..., -0.2578306 ,
#                                     -0.06645986, -1.6516728 ],
#                                    ...,
#                                    [-0.4614277 , -0.04463784, -0.33718762, ...,  0.61219716,
#                                      0.8980533 , -0.8090608 ],
#                                    [-0.88175267, -0.1361453 ,  0.11234064, ..., -1.7225192 ,
#                                      0.02807868,  2.1486378 ],
#                                    [-0.05003111,  1.1730888 ,  0.3687583 , ..., -2.200543  ,
#                                      0.9629967 ,  0.04671486]], dtype=float32)
#                         ),
#                         bias=Weight(
#                             shape=[32],
#                             dtype='float32',
#                             array=array([ 0.01104857,  0.05732181,  0.05125788,  0.00472082,  0.07753469,
#                                    -0.4485782 ,  0.11986297,  0.28385267, -0.00259021,  0.05286436,
#                                     0.16416667, -0.26429483, -0.42408824, -0.5086908 , -0.31537518,
#                                     0.05122508,  0.03500426, -0.12117686, -0.10966038, -0.08444191,
#                                    -0.11277466,  0.20562449, -0.21208555,  0.17816487, -0.00668835,
#                                     0.0813792 ,  0.11644078,  0.11171805,  0.3906766 , -0.342259  ,
#                                     0.35014677, -0.22545353], dtype=float32)
#                         )
#                     ),
#                     relu=ReLU()
#                 ),
#                 tail=FF(
#                     proj=Linear(
#                         weight=Weight(
#                             shape=[64,
#                              32],
#                             dtype='float32',
#                             array=array([[ 0.17141914,  0.57255435,  0.07368395, ...,  0.01299301,
#                                      0.21215531,  0.03131827],
#                                    [-0.02154893, -0.23863705,  0.00742376, ...,  0.03576348,
#                                      0.20583127,  0.68701345],
#                                    [-0.24645597, -0.9868469 ,  0.02452496, ...,  0.8006853 ,
#                                      0.75761074,  0.8367609 ],
#                                    ...,
#                                    [-0.42542428,  0.616034  ,  0.684276  , ..., -1.9834938 ,
#                                     -0.11169055,  1.1704273 ],
#                                    [-0.04128801,  0.39920267,  0.07972243, ..., -0.31776524,
#                                     -0.21360303, -0.02048801],
#                                    [ 0.31885257,  0.9666775 , -0.24310076, ...,  0.43707162,
#                                     -0.17059198,  0.47148976]], dtype=float32)
#                         ),
#                         bias=Weight(
#                             shape=[32],
#                             dtype='float32',
#                             array=array([ 0.42049485,  0.91590726,  0.3375017 ,  0.46364072, -0.15314496,
#                                     0.5866592 ,  0.61890423,  0.64919543,  0.7913698 ,  0.29606944,
#                                     0.70204157,  0.8729803 ,  0.48425716,  0.737307  ,  0.4364337 ,
#                                     0.44171715,  0.5483985 ,  0.47999197,  0.8830009 ,  0.76733977,
#                                     0.6393457 , -0.3315648 ,  0.6757854 ,  0.59121823,  0.9857294 ,
#                                     0.28140035,  0.7006236 ,  0.44390255,  0.53347474,  0.4757561 ,
#                                     0.5370804 ,  0.9358446 ], dtype=float32)
#                         )
#                     ),
#                     relu=ReLU()
#                 ),
#                 root=Weight(
#                     shape=[64],
#                     dtype='float32',
#                     array=array([ 0.03074217,  0.01582592,  0.41385278, -0.05865533, -0.07724947,
#                             0.0676051 , -0.00686863, -0.08781973, -0.21924229,  0.04127427,
#                             0.1258471 ,  0.02500666,  0.05395548, -0.02308797,  0.18711266,
#                            -0.2320352 ,  0.15236196, -0.06845471, -0.09408542,  0.17599086,
#                            -0.18842864, -0.12708865,  0.35144106,  0.14622158, -0.15767504,
#                            -0.08131023, -0.06908582, -0.05038796,  0.08212605,  0.46792617,
#                             0.17990333, -0.06812245,  0.07506642, -0.24636337, -0.11065841,
#                             0.07468522,  0.24916163,  0.00323301,  0.20957789, -0.26015827,
#                            -0.25769472,  0.03059131,  0.24115022,  0.07793614,  0.2952778 ,
#                            -0.01267322,  0.12134629, -0.19878352, -0.01221656,  0.07810827,
#                            -0.25170684, -0.09326925, -0.01243539,  0.03593087,  0.04605369,
#                             0.07760642,  0.04552557,  0.04169129,  0.2662166 , -0.18875073,
#                            -0.03096514, -0.34988707,  0.09674952,  0.26455933], dtype=float32)
#                 ),
#                 kernel=Weight(
#                     shape=[32,
#                      32],
#                     dtype='float32',
#                     array=array([[-0.05147706,  0.05621918, -0.20591006, ..., -0.06650791,
#                              0.11059023,  0.13804491],
#                            [-0.3747542 ,  0.09540477,  0.00798326, ...,  0.00355311,
#                             -0.2576983 ,  0.10503336],
#                            [ 0.08963741, -0.29462937,  0.8249442 , ..., -0.20380053,
#                             -0.10608835, -0.03675904],
#                            ...,
#                            [-0.00651075, -0.03580354, -0.09538957, ...,  0.6259797 ,
#                              0.04300466,  0.00236865],
#                            [-0.08195403, -0.14950131,  0.01717759, ...,  0.12249932,
#                              0.02640214,  0.00243843],
#                            [-0.07015603, -0.04547651, -0.08749429, ...,  0.02818585,
#                              0.08606096,  0.16516112]], dtype=float32)
#                 )
#             ),
#             rel=SyntaxRel(
#                 head=FF(
#                     proj=Linear(
#                         weight=Weight(
#                             shape=[64,
#                              32],
#                             dtype='float32',
#                             array=array([[-0.05884412, -0.4578384 , -0.04877767, ..., -0.03592999,
#                                     -0.00394207,  0.02473774],
#                                    [ 0.03904986, -0.1075078 , -0.04157934, ...,  0.32217047,
#                                      0.06936345, -0.04424147],
#                                    [-0.29516938, -0.19184133, -0.08092368, ..., -0.01148437,
#                                     -0.08100856, -0.06697702],
#                                    ...,
#                                    [ 0.48414898,  0.14814566,  0.6913197 , ..., -0.17128049,
#                                      0.572777  ,  0.37263882],
#                                    [ 0.22782151,  0.09962927,  0.18243301, ...,  0.04593645,
#                                     -0.13634469, -0.07784844],
#                                    [-0.2735953 ,  0.1952439 , -0.11676708, ..., -0.1890363 ,
#                                      0.26232246,  0.15323237]], dtype=float32)
#                         ),
#                         bias=Weight(
#                             shape=[32],
#                             dtype='float32',
#                             array=array([ 0.19805805,  0.2015572 ,  0.18612348, -0.03363091,  0.16653167,
#                                     0.20845257,  0.0941964 ,  0.01985071,  0.01997793,  0.12947215,
#                                     0.0956314 , -0.07225046,  0.05350598,  0.15040097,  0.0606083 ,
#                                     0.02282552, -0.13384813,  0.41703713,  0.15235119,  0.19105846,
#                                     0.0628672 , -0.12175436,  0.07727659, -0.01604945,  0.21919087,
#                                     0.34195352, -0.24103612, -0.07886304,  0.31903172,  0.05545777,
#                                     0.01720983,  0.08331167], dtype=float32)
#                         )
#                     ),
#                     relu=ReLU()
#                 ),
#                 tail=FF(
#                     proj=Linear(
#                         weight=Weight(
#                             shape=[64,
#                              32],
#                             dtype='float32',
#                             array=array([[-0.01483694, -0.5254414 , -0.13328226, ..., -0.4412943 ,
#                                      0.1146907 , -0.27794424],
#                                    [-0.9756892 , -0.10438373, -0.19819075, ..., -0.40632766,
#                                     -0.02217427, -1.033442  ],
#                                    [-0.27869582, -0.23015983, -0.39155582, ..., -0.20331508,
#                                     -0.26475203, -0.51334816],
#                                    ...,
#                                    [ 0.01379759,  0.22828998,  0.18171425, ..., -0.46994764,
#                                      0.6298574 , -0.03039247],
#                                    [ 0.28181407,  0.09741285, -0.0979836 , ...,  0.00511961,
#                                     -0.10262279,  0.04378664],
#                                    [ 0.37042665,  0.12499457, -0.10776005, ..., -0.34260342,
#                                     -0.10037308, -0.04712301]], dtype=float32)
#                         ),
#                         bias=Weight(
#                             shape=[32],
#                             dtype='float32',
#                             array=array([-0.04067142,  0.3733288 , -0.40453324,  0.27714863, -0.07155521,
#                                    -0.29986843, -0.09174652, -0.27350202,  0.04000878, -0.19596   ,
#                                    -0.28256342, -0.3705468 ,  0.16639425, -0.24896899,  0.1221971 ,
#                                    -0.46019754,  0.5628223 ,  0.40891722, -0.33624724, -0.22728732,
#                                     0.19370055, -0.21176556,  0.24854487, -0.41175273,  0.47690326,
#                                    -0.24678285, -0.22768264,  0.5109674 ,  0.2575838 ,  0.01921135,
#                                    -0.2198153 , -0.16182324], dtype=float32)
#                         )
#                     ),
#                     relu=ReLU()
#                 ),
#                 root=Weight(
#                     shape=[64],
#                     dtype='float32',
#                     array=array([-0.15179542, -0.4412126 ,  1.7793492 , -0.73084193,  0.04119493,
#                            -0.24168716,  1.9101611 , -0.45401397, -1.3085197 ,  1.1402203 ,
#                            -1.3184738 , -3.3542871 , -1.086076  , -0.9306399 ,  1.4791614 ,
#                             4.4252324 , -1.3803457 , -0.21475852,  2.586898  ,  1.3716617 ,
#                             2.2013576 , -4.4394164 , -0.95458406,  0.0269098 ,  1.5526723 ,
#                            -0.10224716,  1.3349817 ,  0.87551546, -0.8417622 , -0.21413612,
#                             2.5666115 ,  1.6512294 ,  0.8583146 , -0.9322904 ,  0.21652746,
#                            -2.858759  ,  0.86847806, -2.1305056 ,  2.2009904 , -0.40587538,
#                             1.9176617 ,  0.22281937,  0.8306915 , -1.3897843 ,  2.1516075 ,
#                             0.14464258, -3.2746477 ,  1.3102399 ,  0.7659779 ,  0.24082516,
#                             1.0889628 ,  0.62368864,  2.698835  ,  0.12268224,  1.163735  ,
#                            -1.7064769 , -4.5030594 , -1.0059056 ,  2.9564676 , -0.12711212,
#                            -0.6298868 ,  0.16701199, -2.3734996 ,  0.8141607 ], dtype=float32)
#                 ),
#                 kernel=Weight(
#                     shape=[32,
#                      1440],
#                     dtype='float32',
#                     array=array([[-3.908355  , -3.030627  , -2.7301867 , ..., -1.6796298 ,
#                             -1.8522613 , -0.46748435],
#                            [-3.4454594 , -2.4403813 , -3.2839782 , ..., -2.350877  ,
#                             -3.1342576 , -1.8537618 ],
#                            [-4.345593  , -2.8921475 , -4.115238  , ..., -3.421416  ,
#                             -0.32993907, -0.22923313],
#                            ...,
#                            [-3.4354515 , -2.8682313 , -2.8596911 , ...,  0.40210462,
#                             -0.60911584,  0.31769484],
#                            [-3.1101744 , -2.1475885 , -2.347139  , ..., -2.104374  ,
#                             -2.3786397 , -2.8476095 ],
#                            [-4.8035865 , -3.0579486 , -4.0261726 , ...,  0.21724296,
#                             -0.84683365,  0.45637727]], dtype=float32)
#                 )
#             )
#         ),
#         encoder=SyntaxEncoder(
#             words_vocab=Vocab(items=[...]),
#             shapes_vocab=Vocab(items=[...]),
#             batch_size=8
#         ),
#         decoder=SyntaxDecoder(
#             rels_vocab=Vocab(items=[...])
#         )
#     ),
#     batch_size=8
# )

# %%
sent = "Этим летом стартует новый сезон Paralect Startup Summer 2024 — курса стажировки для Full-Stack Developer. Инженеры из Paralect поделятся с тобой опытом, помогут стать частью реального проекта и справиться с трудностями на всех этапах: от старта до запуска в продакшн. В прошлом году мы приняли более 200 заявок, провели 70 интервью, 12 ребят взяли на курсы и 12 - трудоустроили в Paralect. А самая крутая новость — после прохождения курса у тебя будет возможность получить оффер и стать частью команды Paralect! Немного фактов о Paralect: Команда Paralect — это больше 150 специалистов высокого класса, которые работают над проектами в доменах: FinTech, Insurance, HealthCare, Marketing. Мы не ограничиваемся стандартным технологическим стеком: .Net, Node.js., MongoDB, Kafka, React/Vue, Docker, но и развиваем экспертизу в ML, AI, Blockchain. Что тебя ждет?  Участие в реальном стартапе под присмотром опытных менторов и лекторов; Около 20 теоретических лекций, 21 практическое занятие, 250 часов работы над реальным продуктом, с настоящим фаундером; Практика с такими технологиями, как React, PostCSS, Node.js, MongoDB, Koa, Socket.io, Redis, Git, Docker и др.; Крутые ивенты, тимбилдинги и, конечно же, приятный мерч, куча фоток и видео.  Что для этого необходимо?  Иметь возможность уделять на курсы от 8 часов с понедельника по пятницу; Базовые знания HTML, CSS; Знать основы JavaScript, React, HTTP и Node.js; Владеть английским на уровне Intermediate; Заполнить форму регистрации (её ты можешь получить после отклика); Выполнить тестовое задание, информацию о котором ты сможешь узнать при регистрации на курсы.  Ждем твоего отклика! FAQКогда начинаются курсы и сколько они длятся?  Мы принимаем заявки до 24 мая, затем до 24 июня проводим интервью. Сами курсы будут длиться 2 месяца (с июля по август). Курсы платные? Нет, курсы полностью бесплатные. Какой формат обучения? Курсы будут проходить оффлайн в минском офисе Paralect. Курсы full-time?Да, тебе нужно будет уделять по 8 часов с понедельника по пятницу."

doc = seg_text(sent)
doc
# Out:
# {'text': 'Этим летом стартует новый сезон Paralect Startup Summer 2024 — курса стажировки для Full-Stack Developer. Инженеры из Paralect поделятся с тобой опытом, помогут стать частью реального проекта и справиться с трудностями на всех этапах: от старта до запуска в продакшн. В прошлом году мы приняли более 200 заявок, провели 70 интервью, 12 ребят взяли на курсы и 12 - трудоустроили в Paralect. А самая крутая новость — после прохождения курса у тебя будет возможность получить оффер и стать частью команды Paralect! Немного фактов о Paralect: Команда Paralect — это больше 150 специалистов высокого класса, которые работают над проектами в доменах: FinTech, Insurance, HealthCare, Marketing. Мы не ограничиваемся стандартным технологическим стеком: .Net, Node.js., MongoDB, Kafka, React/Vue, Docker, но и развиваем экспертизу в ML, AI, Blockchain. Что тебя ждет?  Участие в реальном стартапе под присмотром опытных менторов и лекторов; Около 20 теоретических лекций, 21 практическое занятие, 250 часов работы над реальным продуктом, с настоящим фаундером; Практика с такими технологиями, как React, PostCSS, Node.js, MongoDB, Koa, Socket.io, Redis, Git, Docker и др.; Крутые ивенты, тимбилдинги и, конечно же, приятный мерч, куча фоток и видео.  Что для этого необходимо?  Иметь возможность уделять на курсы от 8 часов с понедельника по пятницу; Базовые знания HTML, CSS; Знать основы JavaScript, React, HTTP и Node.js; Владеть английским на уровне Intermediate; Заполнить форму регистрации (её ты можешь получить после отклика); Выполнить тестовое задание, информацию о котором ты сможешь узнать при регистрации на курсы.  Ждем твоего отклика! FAQКогда начинаются курсы и сколько они длятся?  Мы принимаем заявки до 24 мая, затем до 24 июня проводим интервью. Сами курсы будут длиться 2 месяца (с июля по август). Курсы платные? Нет, курсы полностью бесплатные. Какой формат обучения? Курсы будут проходить оффлайн в минском офисе Paralect. Курсы full-time?Да, тебе нужно будет уделять по 8 часов с понедельника по пятницу.',
#  'tokens': [['Этим',
#    'летом',
#    'стартует',
#    'новый',
#    'сезон',
#    'Paralect',
#    'Startup',
#    'Summer',
#    '2024',
#    '—',
#    'курса',
#    'стажировки',
#    'для',
#    'Full-Stack',
#    'Developer',
#    '.'],
#   ['Инженеры',
#    'из',
#    'Paralect',
#    'поделятся',
#    'с',
#    'тобой',
#    'опытом',
#    ',',
#    'помогут',
#    'стать',
#    'частью',
#    'реального',
#    'проекта',
#    'и',
#    'справиться',
#    'с',
#    'трудностями',
#    'на',
#    'всех',
#    'этапах',
#    ':',
#    'от',
#    'старта',
#    'до',
#    'запуска',
#    'в',
#    'продакшн',
#    '.'],
#   ['В',
#    'прошлом',
#    'году',
#    'мы',
#    'приняли',
#    'более',
#    '200',
#    'заявок',
#    ',',
#    'провели',
#    '70',
#    'интервью',
#    ',',
#    '12',
#    'ребят',
#    'взяли',
#    'на',
#    'курсы',
#    'и',
#    '12',
#    '-',
#    'трудоустроили',
#    'в',
#    'Paralect',
#    '.'],
#   ['А',
#    'самая',
#    'крутая',
#    'новость',
#    '—',
#    'после',
#    'прохождения',
#    'курса',
#    'у',
#    'тебя',
#    'будет',
#    'возможность',
#    'получить',
#    'оффер',
#    'и',
#    'стать',
#    'частью',
#    'команды',
#    'Paralect',
#    '!'],
#   ['Немного',
#    'фактов',
#    'о',
#    'Paralect',
#    ':',
#    'Команда',
#    'Paralect',
#    '—',
#    'это',
#    'больше',
#    '150',
#    'специалистов',
#    'высокого',
#    'класса',
#    ',',
#    'которые',
#    'работают',
#    'над',
#    'проектами',
#    'в',
#    'доменах',
#    ':',
#    'FinTech',
#    ',',
#    'Insurance',
#    ',',
#    'HealthCare',
#    ',',
#    'Marketing',
#    '.'],
#   ['Мы',
#    'не',
#    'ограничиваемся',
#    'стандартным',
#    'технологическим',
#    'стеком',
#    ':',
#    '.',
#    'Net',
#    ',',
#    'Node',
#    '.',
#    'js',
#    '.',
#    ',',
#    'MongoDB',
#    ',',
#    'Kafka',
#    ',',
#    'React',
#    '/',
#    'Vue',
#    ',',
#    'Docker',
#    ',',
#    'но',
#    'и',
#    'развиваем',
#    'экспертизу',
#    'в',
#    'ML',
#    ',',
#    'AI',
#    ',',
#    'Blockchain',
#    '.'],
#   ['Что', 'тебя', 'ждет', '?'],
#   ['Участие',
#    'в',
#    'реальном',
#    'стартапе',
#    'под',
#    'присмотром',
#    'опытных',
#    'менторов',
#    'и',
#    'лекторов',
#    ';'],
#   ['Около',
#    '20',
#    'теоретических',
#    'лекций',
#    ',',
#    '21',
#    'практическое',
#    'занятие',
#    ',',
#    '250',
#    'часов',
#    'работы',
#    'над',
#    'реальным',
#    'продуктом',
#    ',',
#    'с',
#    'настоящим',
#    'фаундером',
#    ';'],
#   ['Практика',
#    'с',
#    'такими',
#    'технологиями',
#    ',',
#    'как',
#    'React',
#    ',',
#    'PostCSS',
#    ',',
#    'Node',
#    '.',
#    'js',
#    ',',
#    'MongoDB',
#    ',',
#    'Koa',
#    ',',
#    'Socket',
#    '.',
#    'io',
#    ',',
#    'Redis',
#    ',',
#    'Git',
#    ',',
#    'Docker',
#    'и',
#    'др',
#    '.',
#    ';'],
#   ['Крутые',
#    'ивенты',
#    ',',
#    'тимбилдинги',
#    'и',
#    ',',
#    'конечно',
#    'же',
#    ',',
#    'приятный',
#    'мерч',
#    ',',
#    'куча',
#    'фоток',
#    'и',
#    'видео',
#    '.'],
#   ['Что', 'для', 'этого', 'необходимо', '?'],
#   ['Иметь',
#    'возможность',
#    'уделять',
#    'на',
#    'курсы',
#    'от',
#    '8',
#    'часов',
#    'с',
#    'понедельника',
#    'по',
#    'пятницу',
#    ';'],
#   ['Базовые', 'знания', 'HTML', ',', 'CSS', ';'],
#   ['Знать',
#    'основы',
#    'JavaScript',
#    ',',
#    'React',
#    ',',
#    'HTTP',
#    'и',
#    'Node',
#    '.',
#    'js',
#    ';'],
#   ['Владеть', 'английским', 'на', 'уровне', 'Intermediate', ';'],
#   ['Заполнить',
#    'форму',
#    'регистрации',
#    '(',
#    'её',
#    'ты',
#    'можешь',
#    'получить',
#    'после',
#    'отклика',
#    ')',
#    ';'],
#   ['Выполнить',
#    'тестовое',
#    'задание',
#    ',',
#    'информацию',
#    'о',
#    'котором',
#    'ты',
#    'сможешь',
#    'узнать',
#    'при',
#    'регистрации',
#    'на',
#    'курсы',
#    '.'],
#   ['Ждем', 'твоего', 'отклика', '!'],
#   ['FAQ',
#    'Когда',
#    'начинаются',
#    'курсы',
#    'и',
#    'сколько',
#    'они',
#    'длятся',
#    '?'],
#   ['Мы',
#    'принимаем',
#    'заявки',
#    'до',
#    '24',
#    'мая',
#    ',',
#    'затем',
#    'до',
#    '24',
#    'июня',
#    'проводим',
#    'интервью',
#    '.'],
#   ['Сами',
#    'курсы',
#    'будут',
#    'длиться',
#    '2',
#    'месяца',
#    '(',
#    'с',
#    'июля',
#    'по',
#    'август',
#    ')',
#    '.'],
#   ['Курсы', 'платные', '?'],
#   ['Нет', ',', 'курсы', 'полностью', 'бесплатные', '.'],
#   ['Какой', 'формат', 'обучения', '?'],
#   ['Курсы',
#    'будут',
#    'проходить',
#    'оффлайн',
#    'в',
#    'минском',
#    'офисе',
#    'Paralect',
#    '.'],
#   ['Курсы',
#    'full-time',
#    '?',
#    'Да',
#    ',',
#    'тебе',
#    'нужно',
#    'будет',
#    'уделять',
#    'по',
#    '8',
#    'часов',
#    'с',
#    'понедельника',
#    'по',
#    'пятницу',
#    '.']]}

# %%
syntax_markup = syntax(doc["tokens"][0])

for token_info in syntax_markup.tokens:
    print(token_info)
# Out:
# SyntaxToken(id='1', text='Этим', head_id='2', rel='det')
# SyntaxToken(id='2', text='летом', head_id='3', rel='obl')
# SyntaxToken(id='3', text='стартует', head_id='0', rel='root')
# SyntaxToken(id='4', text='новый', head_id='5', rel='amod')
# SyntaxToken(id='5', text='сезон', head_id='3', rel='nsubj')
# SyntaxToken(id='6', text='Paralect', head_id='5', rel='appos')
# SyntaxToken(id='7', text='Startup', head_id='6', rel='flat:foreign')
# SyntaxToken(id='8', text='Summer', head_id='6', rel='flat:foreign')
# SyntaxToken(id='9', text='2024', head_id='6', rel='flat:foreign')
# SyntaxToken(id='10', text='—', head_id='11', rel='punct')
# SyntaxToken(id='11', text='курса', head_id='5', rel='appos')
# SyntaxToken(id='12', text='стажировки', head_id='11', rel='nmod')
# SyntaxToken(id='13', text='для', head_id='14', rel='case')
# SyntaxToken(id='14', text='Full-Stack', head_id='12', rel='nmod')
# SyntaxToken(id='15', text='Developer', head_id='14', rel='flat:foreign')
# SyntaxToken(id='16', text='.', head_id='3', rel='punct')

# %%
doc = seg_text(sent)
doc = extract_candidates(doc)
doc = syntax_collocations(doc)

print(doc["collocations"])
# Out:
# {'провели интервью', 'Владеть английским', 'ивенты мерч', 'новость прохождения', 'бесплатные бесплатные', 'форму регистрации', 'бесплатные курсы', '24 июня', 'ивенты тимбилдинги', 'специалистов работают', 'частью команды', 'понедельника пятницу', 'работы продуктом', 'приняли году', 'специалистов Команда', 'справиться трудностями', 'стеком технологическим', 'лекций теоретических', 'технологиями такими', 'развиваем экспертизу', 'ивенты куча', 'проходить Курсы', 'работают специалистов', 'офисе минском', 'работают которые', 'июля август', 'менторов лекторов', 'поделятся справиться', 'взяли ребят', 'Иметь возможность', 'информацию котором', 'курсы Сами', 'уделять понедельника', 'мерч приятный', 'получить оффер', 'Ждем отклика', 'возможность получить', 'стеком стандартным', 'Практика технологиями', 'Немного фактов', 'новость крутая', 'месяца июля', 'фаундером настоящим', 'FAQ начинаются', 'отклика твоего', 'длиться курсы', '24 мая', 'приняли заявок', 'поделятся Инженеры', 'регистрации можешь', 'мерч ивенты', 'Знать основы', 'прохождения курса', 'можешь получить', 'узнать информацию', 'ивенты Крутые', 'лекций фаундером', 'React др', 'знания Базовые', 'частью проекта', 'лекций часов', 'Участие присмотром', 'поделятся опытом', 'принимаем проводим', 'сезон новый', 'специалистов класса', 'присмотром менторов', 'задание сможешь', 'стать частью', 'проводим интервью', 'фоток видео', 'сезон курса', 'ограничиваемся развиваем', 'нужно Курсы', 'нужно уделять', 'начинаются длятся', 'занятие практическое', 'курса стажировки', 'Выполнить задание', 'проходить будут', 'крутая самая', 'стартапе реальном', 'году прошлом', 'продуктом реальным', 'развиваем стеком', 'работают доменах', 'уделять курсы', 'формат обучения', 'длиться будут', 'можешь её', 'получить отклика', 'запуска продакшн', 'формат Какой', 'Участие стартапе', 'старта запуска', 'получить стать', 'класса высокого', 'лекций занятие', 'проекта реального', 'регистрации курсы', 'принимаем заявки', 'стартует летом', 'поделятся этапах', 'Заполнить форму', 'взяли трудоустроили', 'Владеть уровне', 'проходить офисе', 'начинаются курсы', 'стартует сезон', 'менторов опытных', 'уделять часов', 'длиться месяца', 'часов работы', 'возможность уделять', 'сможешь узнать', 'задание тестовое', 'лекций лекций', 'будет возможность', 'работают проектами', 'узнать регистрации', 'Курсы платные', 'помогут стать', 'фоток фоток', 'взяли курсы', 'этапах старта'}

# %%
# подключаем urlopen из модуля urllib
from urllib.request import urlopen

# подключаем библиотеку BeautifulSoup
from bs4 import BeautifulSoup

# получаем исходный код страницы
inner_html_code = str(urlopen('https://tyumen.hh.ru/vacancy/98065158?from=applicant_recommended&hhtmFrom=main').read(),'utf-8')

# отправляем исходный код страницы на обработку в библиотеку
inner_soup = BeautifulSoup(inner_html_code, "html.parser")

# выводим содержимое страницы
print(inner_soup.get_text())
# Out:
еМожно из домаОрганизация и дистанционное администрирование деловых и досуговых мероприятий (бизнес встреч, мастер-маиндов, загородных выездов и городского досуга, экстремальных и релакс...Приветствую, меня зовут Дмитрий. - Google таблицы: уверенный пользователь. - Google Календарь: уверенный пользователь. - Английский разговорный и письменный. - Опыт в организации мероприятий. - ОткликнутьсяОткликнутьсяВеб-дизайнерЯндекс КраудТюменьОпыт от 1 года до 3 летМожно из домаРазрабатывать лендинги для разных сервисов Яндекса. Структурировать контент для сайтов, готовить макеты к вёрстке.Уже работали веб-дизайнером. Понимаете пользователей, их поведенческие роли. Мыслите системно, способны видеть продукт целиком. Знакомы с принципами сторителлинга. Работодатель сейчас онлайнОткликнутьсяОткликнутьсяДизайнер мебелиот 70 000 ₽Студия КухниТюменьОпыт от 1 года до 3 летОтклик без резюмеМожно из домаОтрисовка проектов в мебельной программе. Коммуникация с заказчиком. Подготовка документации и подписание договоров. Дистанционная работа.Опыт работы в данном направлении. Умение работать в мебельных программах. Умение коммуницировать с людьми.ОткликнутьсяОткликнутьсяДизайнерот 60 000 ₽Страна ДевелопментТюменьОпыт от 1 года до 3 летМожно из домаВерсткой рекламно-информационных материалов. Разработкой брендинга проектов. Подготовкой презентаций. Разработкой эскизов выставочных стендов. Подготовкой макетов по брендированию мероприятий. Опыт работы в сфере дизайна не менее 1 года. Высшее или средне-специальное образовании в направлении Графического дизайна. ОткликнутьсяОткликнутьсяООО ГРИФОН
# Нет отзывовТюменьHeadHunterПоиск сотрудниковО компанииПомощьНаши вакансииРеклама на сайтеТребования к ПОБезопасный HeadHunterHeadHunter APIПартнерамИнвесторамКаталог компанийРабота по профессиямСоискателямГотовое резюмеВсе сервисыПрофориентацияПродвижение резюмеХочу у вас работатьПроизводственный календарьЭкспертная рекомендацияНовости и статьиРынок трудаЖизнь в компанииИТ-проектыРейтинг работодателей РоссииМолодым специалистамКарьера для молодых специалистовШкола программистовКарьера в некоммерческих организацияхБоты для уведомленийМобильное приложениеЭтика и комплаенсОказание услугИспользование сайтовЗащита персональных данныхПользовательское соглашениеНа информационном ресурсе hh.ru применяются рекомендательные технологии (информационные технологии предоставления информации на основе сбора, систематизации и анализа сведений, относящихся к предпочтениям пользователей сети «Интернет», находящихся на территории Российской Федерации)Switch to English© 2024 ООО «Хэдхантер»
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Подпишитесь на push-уведомления hh.ruПодписатьсяНе сейчас

# %%
get_tags_vacancy(inner_soup.get_text())
# Out:
# {'000',
#  '1',
#  '2024',
#  '27',
#  '27 апрель',
#  '2х',
#  '3',
#  '46',
#  '60',
#  '66',
#  '70',
#  '80',
#  'adobe',
#  'adobe релакс',
#  'after',
#  'amo',
#  'api',
#  'apiпартнераминвесторамкаталог',
#  'bitrix',
#  'coreldraw',
#  'crm',
#  'effects',
#  'english',
#  'english©',
#  'figma',
#  'google',
#  'headhunter',
#  'headhunterheadhunter',
#  'hh',
#  'hhru',
#  'hhruподписатьсяне',
#  'illustrator',
#  'javascript',
#  'photoshop',
#  'photoshopобработка',
#  'pushуведомления',
#  'ru',
#  'switch',
#  'to',
#  'администрирование',
#  'администрирование английский',
#  'администрирование материал',
#  'администрирование отзывпохожий',
#  'администрирование персональный',
#  'администрирование резюмеможный',
#  'администрирование сайтетребование',
#  'адобе',
#  'айдентик',
#  'амо',
#  'анализ',
#  'анастасия',
#  'английский',
#  'апи',
#  'апипартнераминвесторамкаталог',
#  'апрель',
#  'ассистент',
#  'афтер',
#  'база',
#  'база готовый',
#  'база наш',
#  'база оферта',
#  'бизнес',
#  'битриx',
#  'браузер',
#  'браузер ваш',
#  'бренд',
#  'брендинг',
#  'бухгалтер',
#  'ваш',
#  'ввести',
#  'ввести перезагрузить',
#  'ввести текст',
#  'весь',
#  'взаимодействие',
#  'взаимодействие бухгалтер',
#  'взвесить',
#  'видеть',
#  'видеть продукт',
#  'включить',
#  'влиять',
#  'влиять исход',
#  'влиять обучение',
#  'внедрение',
#  'внедрение проект',
#  'возможно',
#  'возможно совмещать',
#  'время',
#  'время время',
#  'время свободный',
#  'встреча',
#  'выбирать',
#  'выбирать дизайнераот',
#  'выбирать попробовать',
#  'выбирать сервис',
#  'выбирать учиться',
#  'выезд',
#  'выплата',
#  'выплата взвесить',
#  'выплата еженедельный',
#  'выплата иметься',
#  'выплата карьерный',
#  'выплата своевременный',
#  'выполнять',
#  'выполнять задача',
#  'высокий',
#  'выставочный',
#  'вёрстка',
#  'год',
#  'гоогле',
#  'городской',
#  'готовить',
#  'готовить макет',
#  'готовый',
#  'грамотный',
#  'график',
#  'график свободный',
#  'графический',
#  'грифон',
#  'грифонпроизойти',
#  'грифонпроизойти ошибка',
#  'дедлайн',
#  'действие',
#  'действие свой',
#  'деловой',
#  'деловой дистанционный',
#  'деловой досуговый',
#  'деловой загородный',
#  'деловой средне-специальный',
#  'дизайн',
#  'дизайн графический',
#  'дизайнделовая',
#  'дизайнераот',
#  'дизайнераот смена',
#  'дистанционный',
#  'дмитрий',
#  'добиться',
#  'добиться желаемый',
#  'добиться эскиз',
#  'договор',
#  'достаточно',
#  'достаточно внедрение',
#  'достаточно прикладывать',
#  'доступ',
#  'доступ завершение',
#  'доступ материал',
#  'досуг',
#  'досуг городской',
#  'досуговый',
#  'еженедельный',
#  'енглиш',
#  'енглиш©',
#  'еффецц',
#  'желаемый',
#  'завершение',
#  'завершение обучение',
#  'загородный',
#  'задача',
#  'задача наш',
#  'задача поставить',
#  'замена',
#  'замена ассистент',
#  'звать',
#  'звать дмитрий',
#  'значит',
#  'значит открыть',
#  'значит подготовка',
#  'значит подписаться',
#  'значит подписатьсян',
#  'значит разговорный',
#  'значит располагаться',
#  'значит связаться',
#  'изображенийфотографияcoreldrawдизайнделовая',
#  'изображенийфотографияцорелдраwдизайнделовая',
#  'иллустратор',
#  'иметься',
#  'инициативный',
#  'интересный',
#  'интернет',
#  'интернет стабильный',
#  'информационный',
#  'искать',
#  'искать поисксоздать',
#  'исход',
#  'исход действие',
#  'исход поддержание',
#  'календарьэкспертный',
#  'картинка',
#  'картинка грифонпроизойти',
#  'карьерный',
#  'контакт',
#  'контент',
#  'контент сайт',
#  'конфиденциальностить',
#  'корпоративный',
#  'магера',
#  'макет',
#  'макет мероприятие',
#  'макет стиль',
#  'мастер-маинд',
#  'материал',
#  'материал выставочный',
#  'материал деловой',
#  'материал полезный',
#  'мебелиот',
#  'мебелиот специалистамкарьер',
#  'мебельный',
#  'мероприятие',
#  'мероприятие высокий',
#  'мероприятие календарьэкспертный',
#  'мероприятие соглашениен',
#  'мини-собеседование',
#  'мир',
#  'мочь',
#  'мочь ваш',
#  'мочь видеть',
#  'мочь принимать',
#  'мочь разбираться',
#  'мочь связаться',
#  'мочь стать',
#  'мыслить',
#  'наблюдение',
#  'наблюдение проджект',
#  'навыкиadobe',
#  'навыкиадобе',
#  'нажимать',
#  'нажимать продолжить',
#  'направление',
#  'направление дизайн',
#  'научить',
#  'научить весь',
#  'научить сам',
#  'находиться',
#  'находиться год',
#  'находиться ресурс',
#  'находиться территория',
#  'наш',
#  'наём',
#  'наём ₽лаборатория',
#  'недвижимость',
#  'необходимо',
#  'необходимо включить',
#  'необходимо искать',
#  'необходимо мочь',
#  'необходимо подтвердить',
#  'необходимо принимать',
#  'необходимо робот',
#  'необходимо текст',
#  'неожиданный',
#  'нет',
#  'нет звать',
#  'нет отзыв',
#  'нет отзывовтюмень',
#  'нет способный',
#  'нет технология',
#  'ноутбук',
#  'нужный',
#  'нужный человек',
#  'обстоятельство',
#  'обстоятельство неожиданный',
#  'обучение',
#  'обучение мини-собеседование',
#  'обязанность',
#  'оказание',
#  'оказание услуга',
#  'ооо',
#  'ооо хэдхантера',
#  'организация',
#  'организация мероприятие',
#  'основа',
#  'основа сбор',
#  'оставлять',
#  'отзыв',
#  'отзыв первымваш',
#  'отзывовтюмень',
#  'отзывовтюмень отзыв',
#  'отзывовтюменьheadhunterпоиск',
#  'отзывовтюменьнаписать',
#  'отзывовтюменьхеадхунтерпоиск',
#  'отзывпохожий',
#  'открыть',
#  'оферта',
#  'ошибка',
#  'партнераминвесторамкаталог',
#  'первымваш',
#  'перезагрузить',
#  'перезагрузить страница',
#  'персональный',
#  'перспектива',
#  'перспектива рост',
#  'писать',
#  'писать требование',
#  'письменный',
#  'пк',
#  'пк ноутбук',
#  'поведенческий',
#  'подготовка',
#  'подготовка встреча',
#  'подготовка макет',
#  'подготовка презентация',
#  'поддержание',
#  'поддержание айдентик',
#  'подписание',
#  'подписание дедлайн',
#  'подписание договор',
#  'подписаться',
#  'подписатьсян',
#  'подтвердить',
#  'подтвердить выбирать',
#  'подтвердить обязанность',
#  'подтверждать',
#  'подтверждать научить',
#  'поисксоздать',
#  'полезный',
#  'политика',
#  'политика конфиденциальностить',
#  'попробовать',
#  'пост',
#  'пост программа',
#  'пост сервис',
#  'пост сеть',
#  'поставить',
#  'презентация',
#  'прикладывать',
#  'прикладывать усилие',
#  'принимать',
#  'принимать готовить',
#  'программа',
#  'программа мебельный',
#  'проджект',
#  'продолжить',
#  'продолжить ввести',
#  'продолжить телефон',
#  'продукт',
#  'проект',
#  'проект база',
#  'проект брендинг',
#  'проект наблюдение',
#  'проект проект',
#  'пушуведомления',
#  'пхотошоп',
#  'пхотошопобработка',
#  'разбираться',
#  'разбираться сфера',
#  'развиваться',
#  'развиваться направление',
#  'разговорный',
#  'разговорный письменный',
#  'разговорный решенияоставить',
#  'разговорный статьирынок',
#  'разный',
#  'располагаться',
#  'резюмеможный',
#  'релакс',
#  'ресурс',
#  'речь',
#  'речь грамотный',
#  'решенияоставить',
#  'робот',
#  'роль',
#  'роль поведенческий',
#  'россиимолодые',
#  'рост',
#  'ру',
#  'сwитч',
#  'сайт',
#  'сайтетребование',
#  'сам',
#  'сбор',
#  'сбор анализ',
#  'сбор выезд',
#  'сбор досуг',
#  'сбор систематизация',
#  'сбор экстремальный',
#  'свободный',
#  'своевременный',
#  'свой',
#  'связаться',
#  'сервис',
#  'сервис интересный',
#  'сервис разный',
#  'сервис яндекс',
#  'сеть',
#  'сеть интернет',
#  'сеть социальный',
#  'систематизация',
#  'случай',
#  'случай обстоятельство',
#  'смена',
#  'смена грифон',
#  'соблюдать',
#  'соблюдать дедлайн',
#  'соблюдать писать',
#  'совмещать',
#  'соглашение',
#  'соглашение оказание',
#  'соглашениен',
#  'содействие',
#  'социальный',
#  'специалистамкарьер',
#  'специалистамкарьер магера',
#  'способный',
#  'средне-специальный',
#  'стабильный',
#  'стать',
#  'стать добиться',
#  'статьирынок',
#  'стенд',
#  'стиль',
#  'стиль корпоративный',
#  'стиль пост',
#  'страница',
#  'строиться',
#  'структурировать',
#  'структурировать взаимодействие',
#  'структурировать вёрстка',
#  'структурировать контент',
#  'структурировать человек',
#  'сфера',
#  'сфера дизайн',
#  'текст',
#  'текст картинка',
#  'текстenglishнажимая',
#  'текстенглишнажимая',
#  'телефон',
#  'телефон отзывовтюменьнаписать',
#  'территория',
#  'территория бренд',
#  'технология',
#  'технология администрирование',
#  'технология анастасия',
#  'технология бизнес',
#  'технология информационный',
#  'технология мастер-маинд',
#  'технология мыслить',
#  'технология наём',
#  'технология оставлять',
#  'технология партнераминвесторамкаталог',
#  'технология подписание',
#  'технология роль',
#  'технология россиимолодые',
#  'технология технология',
#  'то',
#  'точка',
#  'точка контакт',
#  'точка мир',
#  'точка разный',
#  'требование',
#  'требование соблюдать',
#  'требование строиться',
#  'усилие',
#  'услуга',
#  'услуга содействие',
#  'услуга сфера',
#  'учиться',
#  'федерацииswitch',
#  'федерациисwитч',
#  'фигма',
#  'форум',
#  'форум недвижимость',
#  'хеадхунтер',
#  'хеадхунтерхеадхунтер',
#  'хх',
#  'ххру',
#  'ххруподписатьсяне',
#  'хэдхантера',
#  'цорелдраw',
#  'црм',
#  'человек',
#  'человек инициативный',
#  'экстремальный',
#  'эскиз',
#  'эскиз стенд',
#  'явасцрипт',
#  'яндекс',
#  '₽лаборатория'}

# %%
test_df = check({"wi-fi", "cmake", "http", "udp", "stl"}, all_tags, df_all_courses)
json_result = test_df.to_json()
json_result
